# %%
import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd 
import random 
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split, Dataset
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import math
import cv2
import torch.distributions as td
from lib.generate_mask import GenerateMask

# %%
random_seed = 111
origin_dataset = torch.load('moving_minst_data.pt')
total_data_len = len(origin_dataset)
p_miss_num_perc, p_miss_perc, t_miss_num_perc = (0.4,0.8,0.4)

# %%
g_m = GenerateMask(random_seed)
masks = g_m.generate_random_masks(total_data_len,p_miss_num_perc*total_data_len,t_miss_num_perc*total_data_len,p_miss_perc,(origin_dataset[0].size(-2),origin_dataset[0].size(-1)))
torch.save(masks,'moving_minst_data_masks.pt')

# %%
masks = torch.load('moving_minst_data_masks.pt')
dataset=origin_dataset*masks
dataset_m = torch.cat((dataset,masks),dim=1)

# %%
m=len(dataset)
full_data, full_val_data = random_split(origin_dataset, [int(m-m*0.2), int(m*0.2)],generator=torch.Generator().manual_seed(random_seed))
train_data, val_data = random_split(dataset_m, [int(m-m*0.2), int(m*0.2)],generator=torch.Generator().manual_seed(random_seed))
batch_size=256
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):  
        super(VariationalEncoder, self).__init__()

        self.conv1 = nn.Conv2d(1, 16, kernel_size, stride, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size, stride, padding=1)
        self.batch2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 64, kernel_size, stride, padding=1)  
        self.conv4 = nn.Conv2d(64, 128, kernel_size, stride, padding=1)
        self.batch3 = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(128, 256, kernel_size, stride, padding=1)
        self.linear1 = nn.Linear(256*2*2, 128)
        self.linear2 = nn.Linear(128, latent_dims)
        self.linear3 = nn.Linear(128, latent_dims)

        self.N = td.Normal(0, 1)
        self.N.loc = self.N.loc.cuda() # hack to get sampling on the GPU
        self.N.scale = self.N.scale.cuda()
        self.kl = 0
        
    def forward(self, x):
        x = x.to(device)


        x = F.relu(self.conv1(x))
        x = F.relu(self.batch2(self.conv2(x)))
        
        x = F.relu(self.conv3(x))
        
        x = F.relu(self.batch3(self.conv4(x)))
        x = F.relu(self.conv5(x))
      
        x = torch.flatten(x, start_dim=1)
        
        x = F.relu(self.linear1(x))

        mu =  self.linear2(x)
        log_var = self.linear3(x)
        sigma = torch.exp(0.5 * log_var)
        
        rand_state = torch.random.get_rng_state()[0]
        torch.random.manual_seed(rand_state+1)
        z = mu + sigma*self.N.sample(mu.shape)
        self.kl=-0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp(),dim=1)
        # self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        return z

# %%
class Decoder(nn.Module):
    
    def __init__(self, latent_dims):
        super().__init__()

        self.decoder_lin = nn.Sequential(
            nn.Linear(latent_dims, 128),
            nn.ReLU(True),
            nn.Linear(128, 256*2*2),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(256, 2, 2))

        self.decoder_conv = nn.Sequential(

            nn.ConvTranspose2d(256, 128, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 32, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.ConvTranspose2d(32, 16, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 1, kernel_size, stride, padding=1, output_padding=1),
            nn.Upsample(size=(64,64))
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        
        x = torch.sigmoid(x)
        return x

# %%
class GaussianDecoder(Decoder):
    def forward(self, x):
        x = self.decoder_lin(x)
        
        x = self.unflatten(x)
        x = self.decoder_conv(x)

        x = torch.sigmoid(x)
       
        var = torch.ones_like(x)
        
        return td.Normal(loc=x, scale=var)

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = GaussianDecoder(latent_dims)

    def forward(self, x):
        x = x.to(device)
        z = self.encoder(x)
        return self.decoder(z)

# %%
### Set the random seed for reproducible results
torch.manual_seed(random_seed)

kernel_size = [3,3]
stride=[2,2]

d = 20

vae = VariationalAutoencoder(latent_dims=d)

lr = 1e-3 

optim = torch.optim.Adam(vae.parameters(), lr=lr, weight_decay=1e-5)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

vae.to(device)
# Out:
# Selected device: cuda
# VariationalAutoencoder(
#   (encoder): VariationalEncoder(
#     (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (batch2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (batch3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (linear1): Linear(in_features=1024, out_features=128, bias=True)
#     (linear2): Linear(in_features=128, out_features=20, bias=True)
#     (linear3): Linear(in_features=128, out_features=20, bias=True)
#   )
#   (decoder): GaussianDecoder(
#     (decoder_lin): Sequential(
#       (0): Linear(in_features=20, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=1024, bias=True)
#       (3): ReLU(inplace=True)
#     )
#     (unflatten): Unflatten(dim=1, unflattened_size=(256, 2, 2))
#     (decoder_conv): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (10): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU(inplace=True)
#       (12): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (13): Upsample(size=(64, 64), mode=nearest)
#     )
#   )
# )

# %%
### Training function
def train_epoch(vae, device, dataloader, optimizer):
    # Set train mode for both the encoder and the decoder
    vae.train()
    train_loss = 0.0
    nll_loss = 0.0
    kl_loss = 0.0
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for data in dataloader: 
        # Move tensor to the proper device
        x = data[:,:1,:,:]
        mask = data[:,1:,:,:]
        x = x.to(device)
        mask = mask.to(device)
        px_z = vae(x)
        
        # Evaluate loss
        # if all zero in a mask, change back to 1
        temp_mask = mask.squeeze().flatten(1,2)
        mask_sum = temp_mask.sum(1)
        boolen_mask = (mask_sum ==0)
        temp_mask[boolen_mask] = 1
        temp_mask = temp_mask.reshape(mask.shape)

    
      

        nll = (-px_z.log_prob(x)*mask).sum((1,2,3)).mean()

        kl = vae.encoder.kl.mean()

        loss = nll + kl*0.1
        # loss = ((x - x_hat)**2).sum() + vae.encoder.kl
      
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        # print('\t partial train loss (single batch): %f' % (loss.item()))
        nll_loss += nll.item()
        kl_loss += kl.item()

        train_loss+=loss.item()
        

    return train_loss / len(dataloader), nll_loss / len(dataloader), kl_loss / len(dataloader)

# %%
def test_epoch(vae, device, dataloader):
    # Set evaluation mode for encoder and decoder
    vae.eval()
    val_loss = 0.0
    nll_loss = 0.0
    kl_loss = 0.0
    with torch.no_grad(): # No need to track the gradients
        for data in dataloader:
            # Move tensor to the proper device
            x = data[:,:1,:,:]
            mask = data[:,1:,:,:]
            x = x.to(device)
            mask = mask.to(device)
            px_z = vae(x)
        


            # temp_mask = mask.squeeze().flatten(1,2)
            # mask_sum = temp_mask.sum(1)
            # boolen_mask = (mask_sum ==0)
            # temp_mask[boolen_mask] = 1
            # temp_mask = temp_mask.reshape(mask.shape)
           
            # Encode data
            # encoded_data = vae.encoder(x)
            # decoded_data = vae.decoder(encoded_data)
            # print(decoded_data.size())
            # Decode data
            
        # Evaluate loss
            nll = (-px_z.log_prob(x)).sum((1,2,3)).mean()

            kl = vae.encoder.kl.mean()

            loss = nll + kl*0.1
            
            
            # loss = ((x - x_hat)**2).sum() + vae.encoder.kl
            nll_loss += nll.item()
            kl_loss += kl.item()

          
            val_loss += loss.item()

    return val_loss / len(dataloader), nll_loss / len(dataloader), kl_loss / len(dataloader)

# %%
def plot_ae_outputs(encoder,decoder,n=10):
    fig, axs = plt.subplots(10, 2,figsize=(30,100))
    # targets = [item[0] for item in test_data]
    # t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    i=0
    random.seed(random_seed)
    for index in random.sample(range(len(val_data)), n):
      img = val_data[index][:1].unsqueeze(0).to(device)
      
      encoder.eval()
      decoder.eval()
      with torch.no_grad():
         rec_img  = decoder(encoder(img)).mean
         print(encoder(img))
      axs[i,0].imshow(img.cpu().squeeze().numpy(), cmap='gray')
      
      axs[i,1].imshow(rec_img.cpu().squeeze().numpy(), cmap='gray')
      i=i+1

# %%
num_epochs = 200

train_loss_sum = []
train_nll_sum = []
train_kl_sum = []
val_loss_sum = []
val_nll_sum = []
val_kl_sum = []
for epoch in range(num_epochs):
   train_loss,train_nll_loss,train_kl_loss = train_epoch(vae,device,train_loader,optim)
   val_loss,val_nll_loss,val_kl_loss = test_epoch(vae,device,valid_loader)
   train_loss_sum.append(train_loss)
   train_nll_sum.append(train_nll_loss)
   train_kl_sum.append(train_kl_loss)
   val_loss_sum.append(val_loss)
   val_nll_sum.append(val_nll_loss)
   val_kl_sum.append(val_kl_loss)
   print('\n EPOCH {}/{} \t train loss {:.3f} \t train nll loss {:.3f} \t train kl loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,train_nll_loss,train_kl_loss))
   print('\n val loss {:.3f} \t val nll loss {:.3f} \t val kl loss {:.3f}'.format(val_loss,val_nll_loss,val_kl_loss))
   # plot_ae_outputs(vae.encoder,vae.decoder,n=10)
# Out:
#  EPOCH 1/200 	 train loss 2777.395 	 train nll loss 2777.322 	 train kl loss 0.729
#
#  val loss 4090.757 	 val nll loss 4090.752 	 val kl loss 0.045
#
#  EPOCH 2/200 	 train loss 2665.308 	 train nll loss 2665.187 	 train kl loss 1.207
#
#  val loss 3928.237 	 val nll loss 3928.127 	 val kl loss 1.106
#
#  EPOCH 3/200 	 train loss 2612.025 	 train nll loss 2611.454 	 train kl loss 5.713
#
#  val loss 3919.730 	 val nll loss 3919.493 	 val kl loss 2.370
#
#  EPOCH 4/200 	 train loss 2581.556 	 train nll loss 2580.983 	 train kl loss 5.731
#
#  val loss 3887.232 	 val nll loss 3886.840 	 val kl loss 3.918
#
#  EPOCH 5/200 	 train loss 2566.858 	 train nll loss 2566.363 	 train kl loss 4.948
#
#  val loss 3877.124 	 val nll loss 3876.667 	 val kl loss 4.570
#
#  EPOCH 6/200 	 train loss 2558.456 	 train nll loss 2557.868 	 train kl loss 5.880
#
#  val loss 3869.695 	 val nll loss 3869.207 	 val kl loss 4.888
#
#  EPOCH 7/200 	 train loss 2552.913 	 train nll loss 2552.293 	 train kl loss 6.200
#
#  val loss 3938.392 	 val nll loss 3937.669 	 val kl loss 7.226
#
#  EPOCH 8/200 	 train loss 2549.330 	 train nll loss 2548.670 	 train kl loss 6.596
#
#  val loss 3947.422 	 val nll loss 3946.796 	 val kl loss 6.262
#
#  EPOCH 9/200 	 train loss 2546.556 	 train nll loss 2545.928 	 train kl loss 6.283
#
#  val loss 3835.825 	 val nll loss 3835.157 	 val kl loss 6.685
#
#  EPOCH 10/200 	 train loss 2544.392 	 train nll loss 2543.766 	 train kl loss 6.253
#
#  val loss 3831.292 	 val nll loss 3830.639 	 val kl loss 6.530
#
#  EPOCH 11/200 	 train loss 2542.676 	 train nll loss 2542.004 	 train kl loss 6.719
#
#  val loss 3825.155 	 val nll loss 3824.457 	 val kl loss 6.973
#
#  EPOCH 12/200 	 train loss 2540.801 	 train nll loss 2540.129 	 train kl loss 6.721
#
#  val loss 3814.795 	 val nll loss 3814.088 	 val kl loss 7.070
#
#  EPOCH 13/200 	 train loss 2539.481 	 train nll loss 2538.785 	 train kl loss 6.961
#
#  val loss 3807.799 	 val nll loss 3807.041 	 val kl loss 7.581
#
#  EPOCH 14/200 	 train loss 2538.553 	 train nll loss 2537.825 	 train kl loss 7.282
#
#  val loss 3808.815 	 val nll loss 3808.093 	 val kl loss 7.216
#
#  EPOCH 15/200 	 train loss 2537.771 	 train nll loss 2537.036 	 train kl loss 7.358
#
#  val loss 3807.066 	 val nll loss 3806.301 	 val kl loss 7.645
#
#  EPOCH 16/200 	 train loss 2537.192 	 train nll loss 2536.436 	 train kl loss 7.564
#
#  val loss 3805.432 	 val nll loss 3804.658 	 val kl loss 7.735
#
#  EPOCH 17/200 	 train loss 2536.270 	 train nll loss 2535.515 	 train kl loss 7.546
#
#  val loss 3803.609 	 val nll loss 3802.755 	 val kl loss 8.538
#
#  EPOCH 18/200 	 train loss 2535.668 	 train nll loss 2534.886 	 train kl loss 7.824
#
#  val loss 3803.599 	 val nll loss 3802.706 	 val kl loss 8.937
#
#  EPOCH 19/200 	 train loss 2534.981 	 train nll loss 2534.190 	 train kl loss 7.902
#
#  val loss 3798.874 	 val nll loss 3797.997 	 val kl loss 8.770
#
#  EPOCH 20/200 	 train loss 2534.617 	 train nll loss 2533.818 	 train kl loss 7.989
#
#  val loss 3798.190 	 val nll loss 3797.338 	 val kl loss 8.523
#
#  EPOCH 21/200 	 train loss 2534.358 	 train nll loss 2533.543 	 train kl loss 8.156
#
#  val loss 3796.238 	 val nll loss 3795.358 	 val kl loss 8.806
#
#  EPOCH 22/200 	 train loss 2534.072 	 train nll loss 2533.248 	 train kl loss 8.231
#
#  val loss 3792.881 	 val nll loss 3792.033 	 val kl loss 8.475
#
#  EPOCH 23/200 	 train loss 2533.833 	 train nll loss 2532.965 	 train kl loss 8.678
#
#  val loss 3792.658 	 val nll loss 3791.822 	 val kl loss 8.358
#
#  EPOCH 24/200 	 train loss 2533.533 	 train nll loss 2532.685 	 train kl loss 8.474
#
#  val loss 3791.765 	 val nll loss 3790.900 	 val kl loss 8.654
#
#  EPOCH 25/200 	 train loss 2533.388 	 train nll loss 2532.523 	 train kl loss 8.648
#
#  val loss 3790.000 	 val nll loss 3789.117 	 val kl loss 8.825
#
#  EPOCH 26/200 	 train loss 2533.139 	 train nll loss 2532.267 	 train kl loss 8.718
#
#  val loss 3797.964 	 val nll loss 3797.017 	 val kl loss 9.463
#
#  EPOCH 27/200 	 train loss 2533.036 	 train nll loss 2532.165 	 train kl loss 8.704
#
#  val loss 3791.533 	 val nll loss 3790.635 	 val kl loss 8.977
#
#  EPOCH 28/200 	 train loss 2532.699 	 train nll loss 2531.823 	 train kl loss 8.760
#
#  val loss 3786.790 	 val nll loss 3785.871 	 val kl loss 9.190
#
#  EPOCH 29/200 	 train loss 2532.457 	 train nll loss 2531.583 	 train kl loss 8.741
#
#  val loss 3784.766 	 val nll loss 3783.854 	 val kl loss 9.126
#
#  EPOCH 30/200 	 train loss 2532.278 	 train nll loss 2531.318 	 train kl loss 9.608
#
#  val loss 3786.282 	 val nll loss 3785.351 	 val kl loss 9.310
#
#  EPOCH 31/200 	 train loss 2532.057 	 train nll loss 2531.153 	 train kl loss 9.039
#
#  val loss 3786.851 	 val nll loss 3785.920 	 val kl loss 9.310
#
#  EPOCH 32/200 	 train loss 2531.954 	 train nll loss 2531.049 	 train kl loss 9.043
#
#  val loss 3786.541 	 val nll loss 3785.576 	 val kl loss 9.647
#
#  EPOCH 33/200 	 train loss 2531.827 	 train nll loss 2530.919 	 train kl loss 9.075
#
#  val loss 3782.862 	 val nll loss 3781.969 	 val kl loss 8.922
#
#  EPOCH 34/200 	 train loss 2531.607 	 train nll loss 2530.703 	 train kl loss 9.042
#
#  val loss 3784.187 	 val nll loss 3783.247 	 val kl loss 9.403
#
#  EPOCH 35/200 	 train loss 2531.609 	 train nll loss 2530.690 	 train kl loss 9.199
#
#  val loss 3783.874 	 val nll loss 3782.888 	 val kl loss 9.860
#
#  EPOCH 36/200 	 train loss 2531.322 	 train nll loss 2530.394 	 train kl loss 9.276
#
#  val loss 3787.344 	 val nll loss 3786.329 	 val kl loss 10.147
#
#  EPOCH 37/200 	 train loss 2531.227 	 train nll loss 2530.280 	 train kl loss 9.471
#
#  val loss 3781.899 	 val nll loss 3780.973 	 val kl loss 9.264
#
#  EPOCH 38/200 	 train loss 2531.093 	 train nll loss 2530.154 	 train kl loss 9.392
#
#  val loss 3782.999 	 val nll loss 3782.046 	 val kl loss 9.533
#
#  EPOCH 39/200 	 train loss 2531.079 	 train nll loss 2530.141 	 train kl loss 9.371
#
#  val loss 3782.380 	 val nll loss 3781.399 	 val kl loss 9.814
#
#  EPOCH 40/200 	 train loss 2531.018 	 train nll loss 2530.056 	 train kl loss 9.616
#
#  val loss 3782.939 	 val nll loss 3781.944 	 val kl loss 9.949
#
#  EPOCH 41/200 	 train loss 2531.086 	 train nll loss 2530.148 	 train kl loss 9.375
#
#  val loss 3784.914 	 val nll loss 3783.961 	 val kl loss 9.521
#
#  EPOCH 42/200 	 train loss 2531.100 	 train nll loss 2530.159 	 train kl loss 9.415
#
#  val loss 3783.682 	 val nll loss 3782.682 	 val kl loss 10.000
#
#  EPOCH 43/200 	 train loss 2530.620 	 train nll loss 2529.645 	 train kl loss 9.751
#
#  val loss 3783.633 	 val nll loss 3782.636 	 val kl loss 9.969
#
#  EPOCH 44/200 	 train loss 2530.360 	 train nll loss 2529.382 	 train kl loss 9.784
#
#  val loss 3781.785 	 val nll loss 3780.858 	 val kl loss 9.272
#
#  EPOCH 45/200 	 train loss 2530.436 	 train nll loss 2529.451 	 train kl loss 9.856
#
#  val loss 3783.591 	 val nll loss 3782.617 	 val kl loss 9.741
#
#  EPOCH 46/200 	 train loss 2530.270 	 train nll loss 2529.284 	 train kl loss 9.867
#
#  val loss 3782.021 	 val nll loss 3781.015 	 val kl loss 10.064
#
#  EPOCH 47/200 	 train loss 2529.933 	 train nll loss 2528.935 	 train kl loss 9.978
#
#  val loss 3782.063 	 val nll loss 3781.064 	 val kl loss 9.987
#
#  EPOCH 48/200 	 train loss 2529.792 	 train nll loss 2528.776 	 train kl loss 10.160
#
#  val loss 3781.052 	 val nll loss 3780.087 	 val kl loss 9.649
#
#  EPOCH 49/200 	 train loss 2529.721 	 train nll loss 2528.700 	 train kl loss 10.207
#
#  val loss 3780.939 	 val nll loss 3779.925 	 val kl loss 10.142
#
#  EPOCH 50/200 	 train loss 2529.621 	 train nll loss 2528.592 	 train kl loss 10.290
#
#  val loss 3780.348 	 val nll loss 3779.404 	 val kl loss 9.434
#
#  EPOCH 51/200 	 train loss 2529.571 	 train nll loss 2528.554 	 train kl loss 10.171
#
#  val loss 3779.333 	 val nll loss 3778.301 	 val kl loss 10.319
#
#  EPOCH 52/200 	 train loss 2529.420 	 train nll loss 2528.406 	 train kl loss 10.140
#
#  val loss 3780.713 	 val nll loss 3779.660 	 val kl loss 10.532
#
#  EPOCH 53/200 	 train loss 2529.432 	 train nll loss 2528.404 	 train kl loss 10.279
#
#  val loss 3780.948 	 val nll loss 3779.901 	 val kl loss 10.470
#
#  EPOCH 54/200 	 train loss 2529.025 	 train nll loss 2527.985 	 train kl loss 10.404
#
#  val loss 3779.376 	 val nll loss 3778.380 	 val kl loss 9.964
#
#  EPOCH 55/200 	 train loss 2528.966 	 train nll loss 2527.893 	 train kl loss 10.733
#
#  val loss 3781.476 	 val nll loss 3780.451 	 val kl loss 10.247
#
#  EPOCH 56/200 	 train loss 2528.569 	 train nll loss 2527.527 	 train kl loss 10.415
#
#  val loss 3779.526 	 val nll loss 3778.509 	 val kl loss 10.174
#
#  EPOCH 57/200 	 train loss 2528.613 	 train nll loss 2527.541 	 train kl loss 10.719
#
#  val loss 3781.321 	 val nll loss 3780.261 	 val kl loss 10.596
#
#  EPOCH 58/200 	 train loss 2528.485 	 train nll loss 2527.429 	 train kl loss 10.566
#
#  val loss 3781.670 	 val nll loss 3780.677 	 val kl loss 9.930
#
#  EPOCH 59/200 	 train loss 2528.447 	 train nll loss 2527.387 	 train kl loss 10.609
#
#  val loss 3781.584 	 val nll loss 3780.563 	 val kl loss 10.208
#
#  EPOCH 60/200 	 train loss 2528.456 	 train nll loss 2527.395 	 train kl loss 10.606
#
#  val loss 3780.330 	 val nll loss 3779.259 	 val kl loss 10.702
#
#  EPOCH 61/200 	 train loss 2528.438 	 train nll loss 2527.389 	 train kl loss 10.485
#
#  val loss 3778.776 	 val nll loss 3777.730 	 val kl loss 10.463
#
#  EPOCH 62/200 	 train loss 2528.646 	 train nll loss 2527.589 	 train kl loss 10.568
#
#  val loss 3780.403 	 val nll loss 3779.349 	 val kl loss 10.533
#
#  EPOCH 63/200 	 train loss 2528.183 	 train nll loss 2527.120 	 train kl loss 10.623
#
#  val loss 3779.147 	 val nll loss 3778.099 	 val kl loss 10.483
#
#  EPOCH 64/200 	 train loss 2528.125 	 train nll loss 2527.053 	 train kl loss 10.721
#
#  val loss 3779.491 	 val nll loss 3778.439 	 val kl loss 10.523
#
#  EPOCH 65/200 	 train loss 2528.182 	 train nll loss 2527.136 	 train kl loss 10.467
#
#  val loss 3780.361 	 val nll loss 3779.342 	 val kl loss 10.196
#
#  EPOCH 66/200 	 train loss 2528.199 	 train nll loss 2527.136 	 train kl loss 10.632
#
#  val loss 3780.016 	 val nll loss 3778.969 	 val kl loss 10.471
#
#  EPOCH 67/200 	 train loss 2528.135 	 train nll loss 2527.073 	 train kl loss 10.626
#
#  val loss 3778.976 	 val nll loss 3777.955 	 val kl loss 10.209
#
#  EPOCH 68/200 	 train loss 2528.120 	 train nll loss 2527.087 	 train kl loss 10.326
#
#  val loss 3782.080 	 val nll loss 3781.030 	 val kl loss 10.498
#
#  EPOCH 69/200 	 train loss 2527.896 	 train nll loss 2526.831 	 train kl loss 10.649
#
#  val loss 3782.123 	 val nll loss 3781.039 	 val kl loss 10.840
#
#  EPOCH 70/200 	 train loss 2527.659 	 train nll loss 2526.592 	 train kl loss 10.671
#
#  val loss 3779.905 	 val nll loss 3778.842 	 val kl loss 10.624
#
#  EPOCH 71/200 	 train loss 2527.680 	 train nll loss 2526.612 	 train kl loss 10.680
#
#  val loss 3780.309 	 val nll loss 3779.253 	 val kl loss 10.557
#
#  EPOCH 72/200 	 train loss 2527.844 	 train nll loss 2526.764 	 train kl loss 10.805
#
#  val loss 3779.104 	 val nll loss 3778.079 	 val kl loss 10.254
#
#  EPOCH 73/200 	 train loss 2527.820 	 train nll loss 2526.763 	 train kl loss 10.568
#
#  val loss 3779.808 	 val nll loss 3778.799 	 val kl loss 10.088
#
#  EPOCH 74/200 	 train loss 2527.900 	 train nll loss 2526.841 	 train kl loss 10.592
#
#  val loss 3778.692 	 val nll loss 3777.699 	 val kl loss 9.932
#
#  EPOCH 75/200 	 train loss 2527.764 	 train nll loss 2526.700 	 train kl loss 10.645
#
#  val loss 3778.032 	 val nll loss 3776.986 	 val kl loss 10.462
#
#  EPOCH 76/200 	 train loss 2527.717 	 train nll loss 2526.646 	 train kl loss 10.705
#
#  val loss 3778.092 	 val nll loss 3777.091 	 val kl loss 10.009
#
#  EPOCH 77/200 	 train loss 2527.582 	 train nll loss 2526.510 	 train kl loss 10.712
#
#  val loss 3778.366 	 val nll loss 3777.356 	 val kl loss 10.105
#
#  EPOCH 78/200 	 train loss 2527.458 	 train nll loss 2526.385 	 train kl loss 10.725
#
#  val loss 3778.499 	 val nll loss 3777.390 	 val kl loss 11.095
#
#  EPOCH 79/200 	 train loss 2527.639 	 train nll loss 2526.563 	 train kl loss 10.759
#
#  val loss 3778.616 	 val nll loss 3777.530 	 val kl loss 10.855
#
#  EPOCH 80/200 	 train loss 2527.552 	 train nll loss 2526.471 	 train kl loss 10.809
#
#  val loss 3778.648 	 val nll loss 3777.590 	 val kl loss 10.579
#
#  EPOCH 81/200 	 train loss 2527.489 	 train nll loss 2526.412 	 train kl loss 10.778
#
#  val loss 3777.552 	 val nll loss 3776.550 	 val kl loss 10.014
#
#  EPOCH 82/200 	 train loss 2526.927 	 train nll loss 2525.842 	 train kl loss 10.848
#
#  val loss 3776.312 	 val nll loss 3775.338 	 val kl loss 9.733
#
#  EPOCH 83/200 	 train loss 2526.946 	 train nll loss 2525.888 	 train kl loss 10.580
#
#  val loss 3776.315 	 val nll loss 3775.270 	 val kl loss 10.457
#
#  EPOCH 84/200 	 train loss 2526.909 	 train nll loss 2525.845 	 train kl loss 10.640
#
#  val loss 3776.731 	 val nll loss 3775.697 	 val kl loss 10.337
#
#  EPOCH 85/200 	 train loss 2526.816 	 train nll loss 2525.759 	 train kl loss 10.565
#
#  val loss 3777.141 	 val nll loss 3776.057 	 val kl loss 10.843
#
#  EPOCH 86/200 	 train loss 2526.958 	 train nll loss 2525.873 	 train kl loss 10.849
#
#  val loss 3777.703 	 val nll loss 3776.673 	 val kl loss 10.302
#
#  EPOCH 87/200 	 train loss 2527.113 	 train nll loss 2526.045 	 train kl loss 10.678
#
#  val loss 3776.771 	 val nll loss 3775.713 	 val kl loss 10.578
#
#  EPOCH 88/200 	 train loss 2526.934 	 train nll loss 2525.871 	 train kl loss 10.629
#
#  val loss 3776.189 	 val nll loss 3775.161 	 val kl loss 10.276
#
#  EPOCH 89/200 	 train loss 2526.771 	 train nll loss 2525.700 	 train kl loss 10.702
#
#  val loss 3776.712 	 val nll loss 3775.686 	 val kl loss 10.264
#
#  EPOCH 90/200 	 train loss 2526.592 	 train nll loss 2525.505 	 train kl loss 10.865
#
#  val loss 3776.221 	 val nll loss 3775.203 	 val kl loss 10.178
#
#  EPOCH 91/200 	 train loss 2526.540 	 train nll loss 2525.466 	 train kl loss 10.737
#
#  val loss 3776.251 	 val nll loss 3775.220 	 val kl loss 10.306
#
#  EPOCH 92/200 	 train loss 2526.432 	 train nll loss 2525.345 	 train kl loss 10.866
#
#  val loss 3776.553 	 val nll loss 3775.469 	 val kl loss 10.839
#
#  EPOCH 93/200 	 train loss 2526.475 	 train nll loss 2525.408 	 train kl loss 10.672
#
#  val loss 3776.654 	 val nll loss 3775.613 	 val kl loss 10.410
#
#  EPOCH 94/200 	 train loss 2526.450 	 train nll loss 2525.393 	 train kl loss 10.565
#
#  val loss 3776.287 	 val nll loss 3775.257 	 val kl loss 10.296
#
#  EPOCH 95/200 	 train loss 2526.374 	 train nll loss 2525.310 	 train kl loss 10.637
#
#  val loss 3776.486 	 val nll loss 3775.476 	 val kl loss 10.098
#
#  EPOCH 96/200 	 train loss 2526.328 	 train nll loss 2525.270 	 train kl loss 10.578
#
#  val loss 3776.192 	 val nll loss 3775.180 	 val kl loss 10.124
#
#  EPOCH 97/200 	 train loss 2526.426 	 train nll loss 2525.360 	 train kl loss 10.662
#
#  val loss 3776.144 	 val nll loss 3775.151 	 val kl loss 9.936
#
#  EPOCH 98/200 	 train loss 2526.354 	 train nll loss 2525.283 	 train kl loss 10.707
#
#  val loss 3776.872 	 val nll loss 3775.849 	 val kl loss 10.231
#
#  EPOCH 99/200 	 train loss 2526.247 	 train nll loss 2525.190 	 train kl loss 10.572
#
#  val loss 3776.359 	 val nll loss 3775.323 	 val kl loss 10.360
#
#  EPOCH 100/200 	 train loss 2526.056 	 train nll loss 2525.000 	 train kl loss 10.553
#
#  val loss 3775.920 	 val nll loss 3774.950 	 val kl loss 9.701
#
#  EPOCH 101/200 	 train loss 2526.055 	 train nll loss 2524.988 	 train kl loss 10.673
#
#  val loss 3776.598 	 val nll loss 3775.614 	 val kl loss 9.845
#
#  EPOCH 102/200 	 train loss 2526.151 	 train nll loss 2525.077 	 train kl loss 10.738
#
#  val loss 3776.706 	 val nll loss 3775.633 	 val kl loss 10.729
#
#  EPOCH 103/200 	 train loss 2526.266 	 train nll loss 2525.208 	 train kl loss 10.578
#
#  val loss 3777.870 	 val nll loss 3776.831 	 val kl loss 10.391
#
#  EPOCH 104/200 	 train loss 2526.159 	 train nll loss 2525.091 	 train kl loss 10.681
#
#  val loss 3778.734 	 val nll loss 3777.674 	 val kl loss 10.595
#
#  EPOCH 105/200 	 train loss 2526.520 	 train nll loss 2525.453 	 train kl loss 10.672
#
#  val loss 3779.250 	 val nll loss 3778.193 	 val kl loss 10.567
#
#  EPOCH 106/200 	 train loss 2526.644 	 train nll loss 2525.581 	 train kl loss 10.638
#
#  val loss 3777.097 	 val nll loss 3776.037 	 val kl loss 10.602
#
#  EPOCH 107/200 	 train loss 2526.491 	 train nll loss 2525.428 	 train kl loss 10.632
#
#  val loss 3776.071 	 val nll loss 3775.037 	 val kl loss 10.339
#
#  EPOCH 108/200 	 train loss 2526.200 	 train nll loss 2525.152 	 train kl loss 10.474
#
#  val loss 3776.809 	 val nll loss 3775.778 	 val kl loss 10.312
#
#  EPOCH 109/200 	 train loss 2525.837 	 train nll loss 2524.777 	 train kl loss 10.594
#
#  val loss 3777.117 	 val nll loss 3776.116 	 val kl loss 10.009
#
#  EPOCH 110/200 	 train loss 2525.846 	 train nll loss 2524.791 	 train kl loss 10.552
#
#  val loss 3776.203 	 val nll loss 3775.165 	 val kl loss 10.380
#
#  EPOCH 111/200 	 train loss 2525.766 	 train nll loss 2524.704 	 train kl loss 10.623
#
#  val loss 3777.507 	 val nll loss 3776.478 	 val kl loss 10.295
#
#  EPOCH 112/200 	 train loss 2525.822 	 train nll loss 2524.763 	 train kl loss 10.591
#
#  val loss 3777.281 	 val nll loss 3776.269 	 val kl loss 10.123
#
#  EPOCH 113/200 	 train loss 2525.707 	 train nll loss 2524.652 	 train kl loss 10.555
#
#  val loss 3777.480 	 val nll loss 3776.499 	 val kl loss 9.810
#
#  EPOCH 114/200 	 train loss 2525.760 	 train nll loss 2524.690 	 train kl loss 10.693
#
#  val loss 3778.351 	 val nll loss 3777.336 	 val kl loss 10.149
#
#  EPOCH 115/200 	 train loss 2525.736 	 train nll loss 2524.686 	 train kl loss 10.500
#
#  val loss 3777.424 	 val nll loss 3776.396 	 val kl loss 10.273
#
#  EPOCH 116/200 	 train loss 2525.889 	 train nll loss 2524.834 	 train kl loss 10.557
#
#  val loss 3777.871 	 val nll loss 3776.849 	 val kl loss 10.225
#
#  EPOCH 117/200 	 train loss 2525.901 	 train nll loss 2524.832 	 train kl loss 10.696
#
#  val loss 3776.924 	 val nll loss 3775.871 	 val kl loss 10.527
#
#  EPOCH 118/200 	 train loss 2525.918 	 train nll loss 2524.838 	 train kl loss 10.801
#
#  val loss 3777.895 	 val nll loss 3776.831 	 val kl loss 10.633
#
#  EPOCH 119/200 	 train loss 2525.846 	 train nll loss 2524.792 	 train kl loss 10.540
#
#  val loss 3777.964 	 val nll loss 3776.893 	 val kl loss 10.717
#
#  EPOCH 120/200 	 train loss 2525.748 	 train nll loss 2524.697 	 train kl loss 10.517
#
#  val loss 3777.081 	 val nll loss 3776.037 	 val kl loss 10.444
#
#  EPOCH 121/200 	 train loss 2525.591 	 train nll loss 2524.541 	 train kl loss 10.501
#
#  val loss 3777.401 	 val nll loss 3776.366 	 val kl loss 10.349
#
#  EPOCH 122/200 	 train loss 2525.467 	 train nll loss 2524.424 	 train kl loss 10.423
#
#  val loss 3778.007 	 val nll loss 3776.986 	 val kl loss 10.215
#
#  EPOCH 123/200 	 train loss 2525.659 	 train nll loss 2524.592 	 train kl loss 10.671
#
#  val loss 3776.901 	 val nll loss 3775.914 	 val kl loss 9.877
#
#  EPOCH 124/200 	 train loss 2525.597 	 train nll loss 2524.541 	 train kl loss 10.555
#
#  val loss 3776.449 	 val nll loss 3775.432 	 val kl loss 10.175
#
#  EPOCH 125/200 	 train loss 2525.591 	 train nll loss 2524.539 	 train kl loss 10.525
#
#  val loss 3776.361 	 val nll loss 3775.373 	 val kl loss 9.879
#
#  EPOCH 126/200 	 train loss 2525.650 	 train nll loss 2524.584 	 train kl loss 10.659
#
#  val loss 3776.397 	 val nll loss 3775.368 	 val kl loss 10.289
#
#  EPOCH 127/200 	 train loss 2525.684 	 train nll loss 2524.622 	 train kl loss 10.622
#
#  val loss 3776.193 	 val nll loss 3775.152 	 val kl loss 10.418
#
#  EPOCH 128/200 	 train loss 2525.631 	 train nll loss 2524.577 	 train kl loss 10.546
#
#  val loss 3776.160 	 val nll loss 3775.189 	 val kl loss 9.708
#
#  EPOCH 129/200 	 train loss 2525.356 	 train nll loss 2524.310 	 train kl loss 10.459
#
#  val loss 3776.661 	 val nll loss 3775.691 	 val kl loss 9.697
#
#  EPOCH 130/200 	 train loss 2525.403 	 train nll loss 2524.353 	 train kl loss 10.507
#
#  val loss 3776.932 	 val nll loss 3775.922 	 val kl loss 10.099
#
#  EPOCH 131/200 	 train loss 2525.435 	 train nll loss 2524.389 	 train kl loss 10.462
#
#  val loss 3776.846 	 val nll loss 3775.817 	 val kl loss 10.290
#
#  EPOCH 132/200 	 train loss 2525.444 	 train nll loss 2524.388 	 train kl loss 10.555
#
#  val loss 3776.631 	 val nll loss 3775.646 	 val kl loss 9.855
#
#  EPOCH 133/200 	 train loss 2525.668 	 train nll loss 2524.608 	 train kl loss 10.600
#
#  val loss 3777.306 	 val nll loss 3776.332 	 val kl loss 9.740
#
#  EPOCH 134/200 	 train loss 2525.592 	 train nll loss 2524.526 	 train kl loss 10.663
#
#  val loss 3777.115 	 val nll loss 3776.110 	 val kl loss 10.052
#
#  EPOCH 135/200 	 train loss 2525.908 	 train nll loss 2524.848 	 train kl loss 10.591
#
#  val loss 3777.839 	 val nll loss 3776.807 	 val kl loss 10.322
#
#  EPOCH 136/200 	 train loss 2525.730 	 train nll loss 2524.661 	 train kl loss 10.690
#
#  val loss 3777.178 	 val nll loss 3776.158 	 val kl loss 10.199
#
#  EPOCH 137/200 	 train loss 2525.619 	 train nll loss 2524.567 	 train kl loss 10.521
#
#  val loss 3776.785 	 val nll loss 3775.773 	 val kl loss 10.118
#
#  EPOCH 138/200 	 train loss 2525.408 	 train nll loss 2524.354 	 train kl loss 10.537
#
#  val loss 3776.260 	 val nll loss 3775.281 	 val kl loss 9.789
#
#  EPOCH 139/200 	 train loss 2525.209 	 train nll loss 2524.164 	 train kl loss 10.444
#
#  val loss 3776.523 	 val nll loss 3775.499 	 val kl loss 10.241
#
#  EPOCH 140/200 	 train loss 2525.107 	 train nll loss 2524.063 	 train kl loss 10.442
#
#  val loss 3777.765 	 val nll loss 3776.746 	 val kl loss 10.187
#
#  EPOCH 141/200 	 train loss 2525.204 	 train nll loss 2524.157 	 train kl loss 10.463
#
#  val loss 3778.341 	 val nll loss 3777.306 	 val kl loss 10.354
#
#  EPOCH 142/200 	 train loss 2525.260 	 train nll loss 2524.207 	 train kl loss 10.531
#
#  val loss 3777.774 	 val nll loss 3776.756 	 val kl loss 10.186
#
#  EPOCH 143/200 	 train loss 2525.284 	 train nll loss 2524.241 	 train kl loss 10.430
#
#  val loss 3778.354 	 val nll loss 3777.328 	 val kl loss 10.263
#
#  EPOCH 144/200 	 train loss 2525.326 	 train nll loss 2524.262 	 train kl loss 10.639
#
#  val loss 3777.649 	 val nll loss 3776.601 	 val kl loss 10.487
#
#  EPOCH 145/200 	 train loss 2525.138 	 train nll loss 2524.087 	 train kl loss 10.506
#
#  val loss 3777.619 	 val nll loss 3776.630 	 val kl loss 9.885
#
#  EPOCH 146/200 	 train loss 2525.303 	 train nll loss 2524.266 	 train kl loss 10.369
#
#  val loss 3778.915 	 val nll loss 3777.897 	 val kl loss 10.185
#
#  EPOCH 147/200 	 train loss 2525.269 	 train nll loss 2524.237 	 train kl loss 10.314
#
#  val loss 3777.608 	 val nll loss 3776.568 	 val kl loss 10.394
#
#  EPOCH 148/200 	 train loss 2525.360 	 train nll loss 2524.315 	 train kl loss 10.451
#
#  val loss 3778.684 	 val nll loss 3777.651 	 val kl loss 10.333
#
#  EPOCH 149/200 	 train loss 2525.415 	 train nll loss 2524.382 	 train kl loss 10.336
#
#  val loss 3778.657 	 val nll loss 3777.613 	 val kl loss 10.441
#
#  EPOCH 150/200 	 train loss 2525.457 	 train nll loss 2524.395 	 train kl loss 10.621
#
#  val loss 3778.131 	 val nll loss 3777.101 	 val kl loss 10.297
#
#  EPOCH 151/200 	 train loss 2525.309 	 train nll loss 2524.284 	 train kl loss 10.248
#
#  val loss 3777.846 	 val nll loss 3776.827 	 val kl loss 10.184
#
#  EPOCH 152/200 	 train loss 2525.203 	 train nll loss 2524.167 	 train kl loss 10.353
#
#  val loss 3777.889 	 val nll loss 3776.845 	 val kl loss 10.442
#
#  EPOCH 153/200 	 train loss 2525.107 	 train nll loss 2524.074 	 train kl loss 10.339
#
#  val loss 3778.156 	 val nll loss 3777.103 	 val kl loss 10.530
#
#  EPOCH 154/200 	 train loss 2525.092 	 train nll loss 2524.049 	 train kl loss 10.436
#
#  val loss 3777.888 	 val nll loss 3776.861 	 val kl loss 10.274
#
#  EPOCH 155/200 	 train loss 2525.046 	 train nll loss 2524.010 	 train kl loss 10.368
#
#  val loss 3777.586 	 val nll loss 3776.550 	 val kl loss 10.366
#
#  EPOCH 156/200 	 train loss 2525.134 	 train nll loss 2524.103 	 train kl loss 10.311
#
#  val loss 3778.987 	 val nll loss 3777.952 	 val kl loss 10.357
#
#  EPOCH 157/200 	 train loss 2525.178 	 train nll loss 2524.139 	 train kl loss 10.390
#
#  val loss 3777.523 	 val nll loss 3776.524 	 val kl loss 9.993
#
#  EPOCH 158/200 	 train loss 2525.236 	 train nll loss 2524.195 	 train kl loss 10.411
#
#  val loss 3776.553 	 val nll loss 3775.554 	 val kl loss 9.986
#
#  EPOCH 159/200 	 train loss 2525.332 	 train nll loss 2524.289 	 train kl loss 10.424
#
#  val loss 3776.998 	 val nll loss 3775.978 	 val kl loss 10.199
#
#  EPOCH 160/200 	 train loss 2524.996 	 train nll loss 2523.953 	 train kl loss 10.430
#
#  val loss 3778.489 	 val nll loss 3777.502 	 val kl loss 9.873
#
#  EPOCH 161/200 	 train loss 2525.061 	 train nll loss 2524.022 	 train kl loss 10.391
#
#  val loss 3778.319 	 val nll loss 3777.344 	 val kl loss 9.740
#
#  EPOCH 162/200 	 train loss 2524.953 	 train nll loss 2523.917 	 train kl loss 10.367
#
#  val loss 3777.991 	 val nll loss 3776.971 	 val kl loss 10.206
#
#  EPOCH 163/200 	 train loss 2524.914 	 train nll loss 2523.885 	 train kl loss 10.294
#
#  val loss 3777.303 	 val nll loss 3776.300 	 val kl loss 10.032
#
#  EPOCH 164/200 	 train loss 2524.922 	 train nll loss 2523.896 	 train kl loss 10.261
#
#  val loss 3777.235 	 val nll loss 3776.262 	 val kl loss 9.728
#
#  EPOCH 165/200 	 train loss 2524.945 	 train nll loss 2523.906 	 train kl loss 10.389
#
#  val loss 3777.455 	 val nll loss 3776.482 	 val kl loss 9.728
#
#  EPOCH 166/200 	 train loss 2524.989 	 train nll loss 2523.963 	 train kl loss 10.257
#
#  val loss 3777.454 	 val nll loss 3776.444 	 val kl loss 10.099
#
#  EPOCH 167/200 	 train loss 2524.999 	 train nll loss 2523.967 	 train kl loss 10.318
#
#  val loss 3777.171 	 val nll loss 3776.186 	 val kl loss 9.843
#
#  EPOCH 168/200 	 train loss 2524.973 	 train nll loss 2523.940 	 train kl loss 10.337
#
#  val loss 3777.319 	 val nll loss 3776.335 	 val kl loss 9.834
#
#  EPOCH 169/200 	 train loss 2525.062 	 train nll loss 2524.048 	 train kl loss 10.140
#
#  val loss 3777.379 	 val nll loss 3776.373 	 val kl loss 10.057
#
#  EPOCH 170/200 	 train loss 2524.962 	 train nll loss 2523.924 	 train kl loss 10.381
#
#  val loss 3777.490 	 val nll loss 3776.503 	 val kl loss 9.874
#
#  EPOCH 171/200 	 train loss 2525.123 	 train nll loss 2524.090 	 train kl loss 10.329
#
#  val loss 3777.988 	 val nll loss 3776.990 	 val kl loss 9.982
#
#  EPOCH 172/200 	 train loss 2525.092 	 train nll loss 2524.055 	 train kl loss 10.365
#
#  val loss 3777.468 	 val nll loss 3776.507 	 val kl loss 9.619
#
#  EPOCH 173/200 	 train loss 2525.174 	 train nll loss 2524.137 	 train kl loss 10.367
#
#  val loss 3777.264 	 val nll loss 3776.310 	 val kl loss 9.544
#
#  EPOCH 174/200 	 train loss 2525.223 	 train nll loss 2524.176 	 train kl loss 10.466
#
#  val loss 3777.423 	 val nll loss 3776.434 	 val kl loss 9.890
#
#  EPOCH 175/200 	 train loss 2525.255 	 train nll loss 2524.214 	 train kl loss 10.405
#
#  val loss 3776.778 	 val nll loss 3775.783 	 val kl loss 9.946
#
#  EPOCH 176/200 	 train loss 2525.194 	 train nll loss 2524.152 	 train kl loss 10.422
#
#  val loss 3776.745 	 val nll loss 3775.780 	 val kl loss 9.647
#
#  EPOCH 177/200 	 train loss 2525.065 	 train nll loss 2524.031 	 train kl loss 10.349
#
#  val loss 3778.079 	 val nll loss 3777.124 	 val kl loss 9.554
#
#  EPOCH 178/200 	 train loss 2525.015 	 train nll loss 2523.977 	 train kl loss 10.386
#
#  val loss 3776.848 	 val nll loss 3775.891 	 val kl loss 9.573
#
#  EPOCH 179/200 	 train loss 2524.926 	 train nll loss 2523.905 	 train kl loss 10.201
#
#  val loss 3777.267 	 val nll loss 3776.258 	 val kl loss 10.092
#
#  EPOCH 180/200 	 train loss 2524.823 	 train nll loss 2523.795 	 train kl loss 10.283
#
#  val loss 3777.189 	 val nll loss 3776.206 	 val kl loss 9.824
#
#  EPOCH 181/200 	 train loss 2524.746 	 train nll loss 2523.726 	 train kl loss 10.201
#
#  val loss 3776.996 	 val nll loss 3776.002 	 val kl loss 9.940
#
#  EPOCH 182/200 	 train loss 2524.946 	 train nll loss 2523.862 	 train kl loss 10.838
#
#  val loss 3777.688 	 val nll loss 3776.710 	 val kl loss 9.782
#
#  EPOCH 183/200 	 train loss 2524.712 	 train nll loss 2523.691 	 train kl loss 10.207
#
#  val loss 3777.242 	 val nll loss 3776.260 	 val kl loss 9.824
#
#  EPOCH 184/200 	 train loss 2524.775 	 train nll loss 2523.749 	 train kl loss 10.253
#
#  val loss 3777.007 	 val nll loss 3776.041 	 val kl loss 9.664
#
#  EPOCH 185/200 	 train loss 2524.761 	 train nll loss 2523.733 	 train kl loss 10.273
#
#  val loss 3777.607 	 val nll loss 3776.646 	 val kl loss 9.606
#
#  EPOCH 186/200 	 train loss 2524.665 	 train nll loss 2523.648 	 train kl loss 10.174
#
#  val loss 3777.776 	 val nll loss 3776.809 	 val kl loss 9.674
#
#  EPOCH 187/200 	 train loss 2524.782 	 train nll loss 2523.756 	 train kl loss 10.257
#
#  val loss 3776.730 	 val nll loss 3775.760 	 val kl loss 9.692
#
#  EPOCH 188/200 	 train loss 2524.742 	 train nll loss 2523.738 	 train kl loss 10.040
#
#  val loss 3777.321 	 val nll loss 3776.335 	 val kl loss 9.869
#
#  EPOCH 189/200 	 train loss 2524.765 	 train nll loss 2523.753 	 train kl loss 10.120
#
#  val loss 3777.666 	 val nll loss 3776.660 	 val kl loss 10.061
#
#  EPOCH 190/200 	 train loss 2524.804 	 train nll loss 2523.775 	 train kl loss 10.291
#
#  val loss 3777.365 	 val nll loss 3776.393 	 val kl loss 9.715
#
#  EPOCH 191/200 	 train loss 2524.789 	 train nll loss 2523.777 	 train kl loss 10.123
#
#  val loss 3777.253 	 val nll loss 3776.266 	 val kl loss 9.864
#
#  EPOCH 192/200 	 train loss 2524.670 	 train nll loss 2523.652 	 train kl loss 10.182
#
#  val loss 3776.710 	 val nll loss 3775.756 	 val kl loss 9.546
#
#  EPOCH 193/200 	 train loss 2524.732 	 train nll loss 2523.710 	 train kl loss 10.222
#
#  val loss 3777.566 	 val nll loss 3776.590 	 val kl loss 9.765
#
#  EPOCH 194/200 	 train loss 2524.653 	 train nll loss 2523.646 	 train kl loss 10.068
#
#  val loss 3777.803 	 val nll loss 3776.802 	 val kl loss 10.014
#
#  EPOCH 195/200 	 train loss 2524.698 	 train nll loss 2523.666 	 train kl loss 10.315
#
#  val loss 3777.898 	 val nll loss 3776.919 	 val kl loss 9.790
#
#  EPOCH 196/200 	 train loss 2524.718 	 train nll loss 2523.714 	 train kl loss 10.035
#
#  val loss 3778.182 	 val nll loss 3777.201 	 val kl loss 9.804
#
#  EPOCH 197/200 	 train loss 2524.803 	 train nll loss 2523.788 	 train kl loss 10.154
#
#  val loss 3778.267 	 val nll loss 3777.292 	 val kl loss 9.747
#
#  EPOCH 198/200 	 train loss 2524.733 	 train nll loss 2523.709 	 train kl loss 10.238
#
#  val loss 3777.482 	 val nll loss 3776.500 	 val kl loss 9.818
#
#  EPOCH 199/200 	 train loss 2524.611 	 train nll loss 2523.614 	 train kl loss 9.973
#
#  val loss 3777.475 	 val nll loss 3776.503 	 val kl loss 9.718
#
#  EPOCH 200/200 	 train loss 2524.808 	 train nll loss 2523.794 	 train kl loss 10.144
#
#  val loss 3778.173 	 val nll loss 3777.174 	 val kl loss 9.983

# %%
# plot_ae_outputs(vae.encoder,vae.decoder,n=10)

# %%
np.random.seed(random_seed)
random.seed(random_seed)
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)


batch_size = 160
epochs = 200
seqlen = 8

z_size = d
n_hidden = 256
n_gaussians = 10

# %%
# masks = torch.load('moving_minst_data_masks.pt')
# dataset_m=torch.cat((dataset,masks),dim=1)
# full_dataset_m=torch.cat((origin_dataset,masks),dim=1)

# m=len(dataset_m)
# train,validate,test= dataset_m[0:int(0.8*m)],full_dataset_m[0:int(0.8*m)],dataset_m[int(0.8*m):m]
# test_gt = full_dataset_m[int(0.8*m):m]
# print(train.size())
# train_data = train.view(bsz, -1, train.size(1),train.size(2),train.size(3)).to(device)
# print(train_data.size())
# validate_data = validate.view(bsz, -1, validate.size(1),validate.size(2),validate.size(3)).to(device)
# test_data = test.view(bsz, -1, test.size(1),test.size(2),test.size(3)).to(device)
# print(test_data.size())

# %%
origin_dataset = torch.load('moving_minst_data.pt')

masks = torch.load('moving_minst_data_masks.pt')
dataset=origin_dataset*masks
origin_dataset_seq = []
dataset_seq=[]
masks_seq = []
for i in range(0,len(dataset)-(len(dataset)%seqlen),seqlen):
    if(masks[i:i+seqlen, :].sum()==0):
        continue
    origin_dataset_seq.append(origin_dataset[i:i+seqlen, :])
    dataset_seq.append(dataset[i:i+seqlen, :])
    masks_seq.append(masks[i:i+seqlen, :])
origin_dataset_seq=torch.stack(origin_dataset_seq, dim=0)
dataset_seq=torch.stack(dataset_seq, dim=0)
masks_seq=torch.stack(masks_seq, dim=0)

m=len(dataset_seq)


x_train_full,x_val_full = origin_dataset_seq[0:int(0.8*m)],origin_dataset_seq[int(0.8*m):m]
x_train_miss,x_val_miss= dataset_seq[0:int(0.8*m)],dataset_seq[int(0.8*m):m]
m_train_miss, m_val_miss = masks_seq[0:int(0.8*m)],masks_seq[int(0.8*m):m]

# %%
class CustomDataset(Dataset):
    def __init__(self, x, m):
        self.x = x
        self.m = m

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.m[idx]

# %%
batch_size=160
train_dataset = CustomDataset(x_train_miss, m_train_miss)
val_dataset = CustomDataset(x_val_miss, m_val_miss)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size, drop_last=True)
truth_loader = DataLoader(x_val_full, batch_size=batch_size, drop_last=True)

# %%
class MDNRNN(nn.Module):
    def __init__(self, z_size, n_hidden=256, n_gaussians=10, n_layers=1,direction='forward'):
        super(MDNRNN, self).__init__()

        self.z_size = z_size
        self.n_hidden = n_hidden
        self.n_gaussians = n_gaussians
        self.n_layers = n_layers
        self.direction = direction
        
        self.lstm_cell = nn.LSTMCell(z_size,n_hidden)
        self.lstm = nn.LSTM(z_size, n_hidden, n_layers, batch_first=True)
        self.fc1 = nn.Linear(n_hidden, n_gaussians*z_size)
        self.fc2 = nn.Linear(n_hidden, n_gaussians*z_size)
        self.fc3 = nn.Linear(n_hidden, n_gaussians*z_size)
        
    def get_mixture_coef(self, y):
     
        pi, mu, sigma = self.fc1(y), self.fc2(y), self.fc3(y)
        
        pi = pi.view(-1, self.n_gaussians, self.z_size)
        mu = mu.view(-1, self.n_gaussians, self.z_size)
        sigma = sigma.view(-1, self.n_gaussians, self.z_size)

        pi = F.softmax(pi, 1)
        sigma = torch.exp(sigma)
        sigma = abs(sigma)
        return pi, mu, sigma
        
        
    def forward(self, data ,direct=None):

        if not direct:
            direct = self.direction
        
        if direct == "backward":
            data = data.flip(1)
       
        
        input_d = data[:,:,0,:,:] #size(10,6,64,64)
        input_m = data[:,:,1,:,:]

        output_pi = []
        output_mu = []
        output_sigma = []

        predict_result = []
        imputed_result = []
        latent_result = []

        h_c = (torch.zeros(data.size(0), self.n_hidden).to(device),
                torch.zeros(data.size(0), self.n_hidden).to(device))

        for t in range(input_d.size(1)):
            # get predict img by hidden
            h,_ = h_c
            pi, mu, sigma = self.get_mixture_coef(h)

            output_pi.append(pi)
            output_mu.append(mu)
            output_sigma.append(sigma)
          
            pi = pi.unsqueeze(1)
            mu = mu.unsqueeze(1)
            sigma = sigma.unsqueeze(1)
            
      
           
            pi_t=pi.transpose(2, 3)
            pi_t_r=pi_t.reshape(pi_t.size(0)*pi_t.size(1)*pi_t.size(2),pi_t.size(3))

            rand_state = torch.random.get_rng_state()[0]
            torch.random.manual_seed(rand_state)

            k = torch.multinomial(pi_t_r, 1).view(-1)
            
            k_r = k.reshape(pi_t.size(0),pi_t.size(1),pi_t.size(2)).unsqueeze(2)

            torch.random.manual_seed(rand_state+1)
            preds = torch.normal(mu, sigma).gather(2,k_r).squeeze(2).squeeze(1)
            preds_img = vae.decoder(preds).mean
                
            
            predict_result.append(preds_img)
            # combine input image and predict image
            input_t = input_d[:,t,:,:].unsqueeze(1)
            m = input_m[:,t,:,:].unsqueeze(1)
            input_c = input_t*m+preds_img*(1-m)
            imputed_result.append(input_c)
            # Get latent dimension by vae
           
            x = vae.encoder(input_c)

            latent_result.append(x)
            h_c = self.lstm_cell(x,h_c)
            
           

        # predict next image use for imputation next target

      
        
        pi_t = torch.stack(output_pi, dim=1)
        mu_t = torch.stack(output_mu, dim=1)
        sigma_t = torch.stack(output_sigma, dim=1)
        imputations = torch.stack(imputed_result, dim=1)
        predicts= torch.stack(predict_result, dim=1)
        latents = torch.stack(latent_result, dim=1).unsqueeze(2)
        if direct == "backward":
            pi_t=pi_t.flip(1)
            mu_t=mu_t.flip(1)
            sigma_t=sigma_t.flip(1)
            imputations=imputations.flip(1)
            predicts=predicts.flip(1)
            latents = latents.flip(1)
        return (pi_t,mu_t,sigma_t),predicts,imputations,latents

# %%
class BIMDNRNN(nn.Module):
    def __init__(self, z_size, n_hidden=256, n_gaussians=10, n_layers=1):
        super(BIMDNRNN, self).__init__()

        self.z_size = z_size
        self.n_hidden = n_hidden
        self.n_gaussians = n_gaussians
        self.n_layers = n_layers

        self.mdnrnn_f = MDNRNN(z_size, n_hidden,n_gaussians)
        self.mdnrnn_b = MDNRNN(z_size, n_hidden,n_gaussians)
    
    def forward(self,data):
        mdnrnn_f = self.mdnrnn_f(data,'forward')
        mdnrnn_b = self.mdnrnn_b(data,'backward')
        mask =  data[:,:,1,:,:]
        maskweight = torch.sum(mask,(2,3))
       
        d_weight = maskweight.unsqueeze(2)
        
        d_weight_reverse = d_weight.flip(1)
        df_cum_weight = np.cumsum(d_weight.cpu(),1).to(device)
        db_cum_weight = np.cumsum(d_weight_reverse.cpu(),1).flip(1).to(device)
        return self.merge_fnb(mdnrnn_f,mdnrnn_b,df_cum_weight,db_cum_weight,data)


    def merge_fnb(self,mdnrnn_f,mdnrnn_b,df_cum_weight,db_cum_weight,data):
        
        (pi_f, mu_f, sigma_f), predicts_f,imputation_f,latents_f = mdnrnn_f

        (pi_b, mu_b, sigma_b), predicts_b,imputation_b,latents_b = mdnrnn_b
        

        size_view = pi_f.size()
        
        # pi_m = torch.where(df_cum_weight>db_cum_weight,pi_f.flatten(2),pi_b.flatten(2)).view(size_view)
        # mu_m = torch.where(df_cum_weight>db_cum_weight,mu_f.flatten(2),mu_b.flatten(2)).view(size_view)
        # sigma_m = torch.where(df_cum_weight>db_cum_weight,sigma_f.flatten(2),sigma_b.flatten(2)).view(size_view)

        pi_m = torch.cat(((pi_f.flatten(2)*df_cum_weight/(df_cum_weight+db_cum_weight)).view(size_view),(pi_b.flatten(2)*db_cum_weight/(df_cum_weight+db_cum_weight)).view(size_view)),dim=2)
        
        mu_m = torch.cat((mu_f,mu_b),dim=2)
   
        sigma_m = torch.cat((sigma_f,sigma_b),dim=2)
        
        predict_size = predicts_f.size()
        imputaion_size = imputation_f.size()
        latent_size = latents_f.size()

        # predicts_m = torch.where(df_cum_weight>db_cum_weight,predicts_f.flatten(2),predicts_b.flatten(2)).view(predict_size)
        # imputation_m = torch.where(df_cum_weight>db_cum_weight,imputation_f.flatten(2),imputation_b.flatten(2)).view(imputaion_size)
        predicts_m = ((predicts_f.flatten(2)*df_cum_weight + predicts_b.flatten(2)*db_cum_weight)/(df_cum_weight+db_cum_weight)).view(predict_size)
        imputation_m = ((imputation_f.flatten(2)*df_cum_weight + imputation_b.flatten(2)*db_cum_weight)/(df_cum_weight+db_cum_weight)).view(imputaion_size)
        latents_m = ((latents_f.flatten(2)*df_cum_weight + latents_b.flatten(2)*db_cum_weight)/(df_cum_weight+db_cum_weight)).view(latent_size)
        # latents_m = []
        # for i in range(seqlen):
        #     latents_m.append(vae.encoder(imputation_m[:,i,:]))
        # latents_m = torch.stack(latents_m, dim=1).unsqueeze(2)
        
        return (pi_m,mu_m,sigma_m),predicts_m,imputation_m,latents_m

# %%
model = BIMDNRNN(z_size, n_hidden,n_gaussians).to(device)

# %%
def mdn_loss_fn(y, pi, mu, sigma):
    m = torch.distributions.Normal(loc=mu, scale=sigma)
    loss = torch.exp(m.log_prob(y))
    loss = torch.sum(loss * pi, dim=2)
    loss = -torch.log(loss)
    return loss.mean()

# %%
def criterion(y, pi, mu, sigma,latents):
    # input = y[:,:,0,:,:].unsqueeze(2)
    # m = y[:,:,1,:,:].unsqueeze(2)
    # input_c = input*m+imputation*(1-m)
    # x_list = []
    # for i in range(input_c.size(1)):
    #     input_img = input_c[:,i,:,:,:]
    #     x = vae.encoder(input_img)
    #     x_list.append(x)
    # target = torch.stack(x_list,dim=1).unsqueeze(2)
    
    
    return mdn_loss_fn(latents, pi, mu, sigma)

# %%
optimizer = torch.optim.Adam(model.parameters())

# %%
for epoch in range(epochs):
    # Set initial hidden and cell states
    train_loss = 0
    prediction_loss = 0
    imputation_loss = 0
    
    for x, masks in train_loader:
        optimizer.zero_grad()
        # Get mini-batch inputs and targets
        inputs = torch.cat((x,masks),dim=2).to(device)
       
        # Forward pass
        (pi, mu, sigma),predict, imputation,latents = model(inputs)
        
        loss = mdn_loss_fn(latents, pi, mu, sigma)
        
        # Backward and optimize
        
        loss.backward()
        # clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
        train_loss += loss.item()
    
    # for (x, masks), y_img in zip(valid_loader,truth_loader):
        
    #     model.eval()
    #     with torch.no_grad():
    #         x = x.to(device)
    #         masks = masks.to(device)
    #         inputs = torch.cat((x,masks),dim=2)
    #         y_img = y_img.to(device)
    #         (pi, mu, sigma),predicts, imputation,latents = model(inputs)
         
          
    #         predict_loss = ((y_img-predicts)**2).sum()
    #         impute_loss= (((y_img-imputation)*(1-masks))**2).sum()
          
    #         prediction_loss += predict_loss.item()
    #         imputation_loss += impute_loss.item()

    print ('Epoch [{}/{}], Loss: {:.4f}'
               .format(epoch+1, num_epochs, train_loss))
# Out:
# Epoch [1/200], Loss: 7.8062
# Epoch [2/200], Loss: 7.7016
# Epoch [3/200], Loss: 7.6299
# Epoch [4/200], Loss: 7.5825
# Epoch [5/200], Loss: 7.4884
# Epoch [6/200], Loss: 7.3971
# Epoch [7/200], Loss: 7.3462
# Epoch [8/200], Loss: 7.3290
# Epoch [9/200], Loss: 7.3401
# Epoch [10/200], Loss: 7.2884
# Epoch [11/200], Loss: 7.2696
# Epoch [12/200], Loss: 7.2213
# Epoch [13/200], Loss: 7.2484
# Epoch [14/200], Loss: 7.1946
# Epoch [15/200], Loss: 7.1987
# Epoch [16/200], Loss: 7.1449
# Epoch [17/200], Loss: 7.1499
# Epoch [18/200], Loss: 7.1274
# Epoch [19/200], Loss: 7.1007
# Epoch [20/200], Loss: 7.1236
# Epoch [21/200], Loss: 7.1086
# Epoch [22/200], Loss: 7.0654
# Epoch [23/200], Loss: 7.0397
# Epoch [24/200], Loss: 7.0251
# Epoch [25/200], Loss: 7.0214
# Epoch [26/200], Loss: 6.9851
# Epoch [27/200], Loss: 6.9387
# Epoch [28/200], Loss: 6.9436
# Epoch [29/200], Loss: 6.9724
# Epoch [30/200], Loss: 6.9568
# Epoch [31/200], Loss: 6.9002
# Epoch [32/200], Loss: 6.8561
# Epoch [33/200], Loss: 6.8413
# Epoch [34/200], Loss: 6.8597
# Epoch [35/200], Loss: 6.8245
# Epoch [36/200], Loss: 6.7968
# Epoch [37/200], Loss: 6.7605
# Epoch [38/200], Loss: 6.7909
# Epoch [39/200], Loss: 6.7741
# Epoch [40/200], Loss: 6.7523
# Epoch [41/200], Loss: 6.6978
# Epoch [42/200], Loss: 6.7380
# Epoch [43/200], Loss: 6.7370
# Epoch [44/200], Loss: 6.6850
# Epoch [45/200], Loss: 6.6544
# Epoch [46/200], Loss: 6.6906
# Epoch [47/200], Loss: 6.6948
# Epoch [48/200], Loss: 6.6515
# Epoch [49/200], Loss: 6.6134
# Epoch [50/200], Loss: 6.6309
# Epoch [51/200], Loss: 6.6385
# Epoch [52/200], Loss: 6.6066
# Epoch [53/200], Loss: 6.5901
# Epoch [54/200], Loss: 6.5762
# Epoch [55/200], Loss: 6.6052
# Epoch [56/200], Loss: 6.5908
# Epoch [57/200], Loss: 6.5415
# Epoch [58/200], Loss: 6.5922
# Epoch [59/200], Loss: 6.5382
# Epoch [60/200], Loss: 6.5934
# Epoch [61/200], Loss: 6.4825
# Epoch [62/200], Loss: 6.5198
# Epoch [63/200], Loss: 6.4929
# Epoch [64/200], Loss: 6.5207
# Epoch [65/200], Loss: 6.4397
# Epoch [66/200], Loss: 6.4794
# Epoch [67/200], Loss: 6.4581
# Epoch [68/200], Loss: 6.4504
# Epoch [69/200], Loss: 6.3867
# Epoch [70/200], Loss: 6.4003
# Epoch [71/200], Loss: 6.4160
# Epoch [72/200], Loss: 6.3978
# Epoch [73/200], Loss: 6.3475
# Epoch [74/200], Loss: 6.3514
# Epoch [75/200], Loss: 6.3469
# Epoch [76/200], Loss: 6.3803
# Epoch [77/200], Loss: 6.2744
# Epoch [78/200], Loss: 6.3381
# Epoch [79/200], Loss: 6.2888
# Epoch [80/200], Loss: 6.3826
# Epoch [81/200], Loss: 6.2099
# Epoch [82/200], Loss: 6.3223
# Epoch [83/200], Loss: 6.2373
# Epoch [84/200], Loss: 6.3216
# Epoch [85/200], Loss: 6.1560
# Epoch [86/200], Loss: 6.2879
# Epoch [87/200], Loss: 6.1952
# Epoch [88/200], Loss: 6.2292
# Epoch [89/200], Loss: 6.1613
# Epoch [90/200], Loss: 6.1967
# Epoch [91/200], Loss: 6.2337
# Epoch [92/200], Loss: 6.1379
# Epoch [93/200], Loss: 6.1374
# Epoch [94/200], Loss: 6.1045
# Epoch [95/200], Loss: 6.2175
# Epoch [96/200], Loss: 6.0815
# Epoch [97/200], Loss: 6.0831
# Epoch [98/200], Loss: 6.0375
# Epoch [99/200], Loss: 6.1416
# Epoch [100/200], Loss: 6.0759
# Epoch [101/200], Loss: 6.0158
# Epoch [102/200], Loss: 6.0082
# Epoch [103/200], Loss: 6.0556
# Epoch [104/200], Loss: 6.0165
# Epoch [105/200], Loss: 5.9835
# Epoch [106/200], Loss: 5.9753
# Epoch [107/200], Loss: 6.0693
# Epoch [108/200], Loss: 5.9501
# Epoch [109/200], Loss: 5.9655
# Epoch [110/200], Loss: 5.8831
# Epoch [111/200], Loss: 6.0508
# Epoch [112/200], Loss: 5.9111
# Epoch [113/200], Loss: 5.9774
# Epoch [114/200], Loss: 5.8556
# Epoch [115/200], Loss: 5.9814
# Epoch [116/200], Loss: 5.9235
# Epoch [117/200], Loss: 5.8651
# Epoch [118/200], Loss: 5.8844
# Epoch [119/200], Loss: 5.8662
# Epoch [120/200], Loss: 5.9388
# Epoch [121/200], Loss: 5.7673
# Epoch [122/200], Loss: 5.8954
# Epoch [123/200], Loss: 5.8092
# Epoch [124/200], Loss: 5.8936
# Epoch [125/200], Loss: 5.7623
# Epoch [126/200], Loss: 5.7756
# Epoch [127/200], Loss: 5.7857
# Epoch [128/200], Loss: 5.8159
# Epoch [129/200], Loss: 5.7438
# Epoch [130/200], Loss: 5.6977
# Epoch [131/200], Loss: 5.7407
# Epoch [132/200], Loss: 5.7888
# Epoch [133/200], Loss: 5.7280
# Epoch [134/200], Loss: 5.6749
# Epoch [135/200], Loss: 5.7037
# Epoch [136/200], Loss: 5.7404
# Epoch [137/200], Loss: 5.7109
# Epoch [138/200], Loss: 5.6471
# Epoch [139/200], Loss: 5.6858
# Epoch [140/200], Loss: 5.7123
# Epoch [141/200], Loss: 5.6830
# Epoch [142/200], Loss: 5.6429
# Epoch [143/200], Loss: 5.6720
# Epoch [144/200], Loss: 5.6772
# Epoch [145/200], Loss: 5.6586
# Epoch [146/200], Loss: 5.6336
# Epoch [147/200], Loss: 5.6046
# Epoch [148/200], Loss: 5.6991
# Epoch [149/200], Loss: 5.6295
# Epoch [150/200], Loss: 5.6139
# Epoch [151/200], Loss: 5.5833
# Epoch [152/200], Loss: 5.6306
# Epoch [153/200], Loss: 5.6438
# Epoch [154/200], Loss: 5.5651
# Epoch [155/200], Loss: 5.5559
# Epoch [156/200], Loss: 5.5699
# Epoch [157/200], Loss: 5.6009
# Epoch [158/200], Loss: 5.5195
# Epoch [159/200], Loss: 5.4532
# Epoch [160/200], Loss: 5.5125
# Epoch [161/200], Loss: 5.5283
# Epoch [162/200], Loss: 5.4700
# Epoch [163/200], Loss: 5.4086
# Epoch [164/200], Loss: 5.4536
# Epoch [165/200], Loss: 5.4968
# Epoch [166/200], Loss: 5.4712
# Epoch [167/200], Loss: 5.3771
# Epoch [168/200], Loss: 5.4471
# Epoch [169/200], Loss: 5.4232
# Epoch [170/200], Loss: 5.4385
# Epoch [171/200], Loss: 5.3521
# Epoch [172/200], Loss: 5.3883
# Epoch [173/200], Loss: 5.4020
# Epoch [174/200], Loss: 5.4102
# Epoch [175/200], Loss: 5.3447
# Epoch [176/200], Loss: 5.3388
# Epoch [177/200], Loss: 5.3736
# Epoch [178/200], Loss: 5.3586
# Epoch [179/200], Loss: 5.3469
# Epoch [180/200], Loss: 5.3216
# Epoch [181/200], Loss: 5.3473
# Epoch [182/200], Loss: 5.3216
# Epoch [183/200], Loss: 5.2795
# Epoch [184/200], Loss: 5.3026
# Epoch [185/200], Loss: 5.3126
# Epoch [186/200], Loss: 5.3124
# Epoch [187/200], Loss: 5.2331
# Epoch [188/200], Loss: 5.2870
# Epoch [189/200], Loss: 5.2888
# Epoch [190/200], Loss: 5.2618
# Epoch [191/200], Loss: 5.2080
# Epoch [192/200], Loss: 5.2362
# Epoch [193/200], Loss: 5.2659
# Epoch [194/200], Loss: 5.2255
# Epoch [195/200], Loss: 5.2147
# Epoch [196/200], Loss: 5.2190
# Epoch [197/200], Loss: 5.2373
# Epoch [198/200], Loss: 5.1988
# Epoch [199/200], Loss: 5.1735
# Epoch [200/200], Loss: 5.2151

# %%
# def ssim(img1, img2):
#     C1 = (0.01 * 1)**2
#     C2 = (0.03 * 1)**2

#     kernel = cv2.getGaussianKernel(11, 1.5)
#     window = np.outer(kernel, kernel.transpose())

#     mu1 = cv2.filter2D(img1, -1, window)[5:-5, 5:-5]  # valid
#     mu2 = cv2.filter2D(img2, -1, window)[5:-5, 5:-5]
#     mu1_sq = mu1**2
#     mu2_sq = mu2**2
#     mu1_mu2 = mu1 * mu2
#     sigma1_sq = cv2.filter2D(img1**2, -1, window)[5:-5, 5:-5] - mu1_sq
#     sigma2_sq = cv2.filter2D(img2**2, -1, window)[5:-5, 5:-5] - mu2_sq
#     sigma12 = cv2.filter2D(img1 * img2, -1, window)[5:-5, 5:-5] - mu1_mu2

#     ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) *
#                                                             (sigma1_sq + sigma2_sq + C2))
#     return ssim_map.mean()


# def calculate_ssim(img1, img2):
#     '''calculate SSIM
#     the same outputs as MATLAB's
#     img1, img2: [0, 255]
#     '''
#     if not img1.shape == img2.shape:
#         raise ValueError('Input images must have the same dimensions.')
#     if img1.ndim == 2:
#         return ssim(img1, img2)
#     elif img1.ndim == 3:
#         if img1.shape[2] == 3:
#             ssims = []
#             for i in range(3):
#                 ssims.append(ssim(img1, img2))
#             return np.array(ssims).mean()
#         elif img1.shape[2] == 1:
#             return ssim(np.squeeze(img1), np.squeeze(img2))
#     else:
#         raise ValueError('Wrong input image dimensions.')

# %%
# test_predict_loss = 0.0
# test_impu_loss = 0.0
# test_impu_part_loss = 0.0
# impuated_data_sum = 0
# test_psnr = 0
# test_ssim =0
# input_dataset = x_val_miss
# compare_dataset = x_val_full
# with torch.no_grad():
#     for i in range(len(x_val_miss)):

#         x = input_dataset[i].to(device)
#         y_img = compare_dataset[i].to(device)
#         image_mask = m_val_miss[i].to(device)
#         input = torch.cat((x,image_mask),dim=1).unsqueeze(0)
      
#         (pi, mu, sigma),predicts, imputation,latents = model(input)
      
#         # predicts = vae.decoder(vae.encoder(imputation[0])).mean
#         predicts = vae.decoder(latents.squeeze()).mean
#         impuated_data_sum+=(image_mask.flatten()==0).sum().item()
#         impuated_parts = predicts*(1-image_mask)
#         full_parts = y_img*(1-image_mask)
        
#         loss_p = (abs(predicts - y_img)/(predicts.size(-1)*predicts.size(-2))).sum()/seqlen
#         loss_ip = abs(impuated_parts - full_parts).sum()
#         mse = (((predicts- y_img)**2)/(predicts.size(-1)*predicts.size(-2))).sum()/seqlen

#         psnr = 20*math.log10(1/math.sqrt(mse))

#         test_psnr += psnr
       
#         test_predict_loss += loss_p.item()
       
#         test_impu_part_loss += loss_ip.item()
#         ssim_p = 0
#         for j in range(len(predicts.squeeze())):
#             ssim_p += ssim(predicts.squeeze()[j].squeeze().cpu().detach().numpy(),y_img.squeeze()[j].squeeze().cpu().detach().numpy())
#         test_ssim +=ssim_p/seqlen
       


# print(test_predict_loss / len(input_dataset))
# print(test_impu_part_loss / impuated_data_sum)
# print(test_psnr / len(input_dataset))
# print(test_ssim / len(input_dataset))

# %% [markdown]
# 0.030602442547678948
# 0.04794726518177093
# 18.373459759169872
# 0.8157171804308895
#
# 0.0316610941849649
# 0.0505340079886593
# 18.09755197754493
# 0.8067896990180017

# %%
one = np.random.randint(len(x_val_miss))

one = 2

x = x_val_miss[one].to(device)
mask = m_val_miss[one].to(device)

input = torch.cat((x,mask),dim=1).unsqueeze(0)
y_origin = x_val_full[one].to(device)

(pi, mu, sigma),predicts, imputation,latents = model(input)



predicts_v = vae.decoder(latents.squeeze()).mean

imputated_result = predicts_v*(1-mask)+input[0][:,:1,:]*mask
# y_preds = [torch.normal(mu, sigma)[:, :, i, :] for i in range(n_gaussians)]

# y_preds=torch.sum((torch.normal(mu, sigma)*pi),dim=2)

# y_preds  = torch.normal(mu, sigma).gather(2,pi.max(2)[1].unsqueeze(2)).squeeze(2)

# pi_t=pi.transpose(2, 3)
# pi_t_r=pi_t.reshape(pi_t.size(0)*pi_t.size(1)*pi_t.size(2),pi_t.size(3))
# k = torch.multinomial(pi_t_r, 1).view(-1)
# k_r = k.reshape(pi_t.size(0),pi_t.size(1),pi_t.size(2)).unsqueeze(2)
# y_preds = torch.normal(mu, sigma).gather(2,k_r).squeeze(2)

# compare_result=torch.cat([x,y]+y_preds)
fig, axs = plt.subplots(seqlen, 6,figsize=(30,seqlen*8))
for index in range(seqlen):
    vae.decoder.eval()
    with torch.no_grad():
        
        # imputed_img =imputation[0][index][0]
        imputed_img = imputated_result[index][0]
        predict_img =predicts[0][index][0]
        im_img =imputation[0][index][0]
        axs[index,0].imshow(x[index][0].cpu().squeeze().numpy(), cmap='gray')
        axs[index,1].imshow(predict_img.cpu().squeeze().numpy(), cmap='gray')
        axs[index,2].imshow(im_img.cpu().squeeze().numpy(), cmap='gray')
        axs[index,3].imshow(predicts_v[index][0].cpu().squeeze().numpy(), cmap='gray')
        axs[index,4].imshow(imputed_img.cpu().squeeze().numpy(), cmap='gray')
        axs[index,5].imshow(y_origin[index][0].cpu().squeeze().numpy(), cmap='gray')
# for z_result in compare_result:
#     vae.decoder.eval()
#     with torch.no_grad():
#         d_image=vae.decoder(z_result)
#         plt.imshow(d_image.cpu().squeeze().numpy(), cmap='gray')
#         plt.show()

# %%
one = np.random.randint(len(x_val_miss))

one = 2

x = x_val_miss[one].to(device)
mask = m_val_miss[one].to(device)

input = torch.cat((x,mask),dim=1)
y_origin = x_val_full[one].to(device)

fig, axs = plt.subplots(8, 3,figsize=(30,100))
for index in range(input.size(0)):
   
    img = input[index][:1].unsqueeze(0).to(device)
    
    img_mask = input[index][1:].unsqueeze(0).to(device)
   
    vae.encoder.eval()
    vae.decoder.eval()
    with torch.no_grad():
        rec_img  = vae.decoder(vae.encoder(img)).mean
    imputated_result = rec_img*(1-img_mask)+img*img_mask
    axs[index,0].imshow(img.cpu().squeeze().numpy(), cmap='gray')
    axs[index,1].imshow(rec_img.cpu().squeeze().numpy(), cmap='gray')
    axs[index,2].imshow(imputated_result.cpu().squeeze().numpy(), cmap='gray')
