# %%
import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd 
import random 
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split, Dataset
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import math
import cv2
import torch.distributions as td

# %%
random_seed = 1111

torch.manual_seed(random_seed)

kernel_size = [3,3]
stride=[2,2]

d = 20

# %%
origin_dataset = torch.load('moving_minst_data.pt')
masks = torch.load('moving_minst_data_masks.pt')
dataset=origin_dataset*masks
dataset_m = torch.cat((dataset,masks),dim=1)

# %%
m=len(dataset)
full_data, full_val_data = random_split(origin_dataset, [int(m-m*0.2), int(m*0.2)],generator=torch.Generator().manual_seed(random_seed))
train_data, val_data = random_split(dataset_m, [int(m-m*0.2), int(m*0.2)],generator=torch.Generator().manual_seed(random_seed))
batch_size=16
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):  
        super(VariationalEncoder, self).__init__()

        self.conv1 = nn.Conv2d(1, 16, kernel_size, stride, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size, stride, padding=1)
        self.batch2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 64, kernel_size, stride, padding=1)  
        self.conv4 = nn.Conv2d(64, 128, kernel_size, stride, padding=1)
        self.batch3 = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(128, 256, kernel_size, stride, padding=1)
        self.linear1 = nn.Linear(256*2*2, 128)
        self.linear2 = nn.Linear(128, latent_dims)
        self.linear3 = nn.Linear(128, latent_dims)

        self.N = td.Normal(0, 1)
        self.N.loc = self.N.loc.cuda() # hack to get sampling on the GPU
        self.N.scale = self.N.scale.cuda()
        self.kl = 0
        
    def forward(self, x):
        x = x.to(device)


        x = F.relu(self.conv1(x))
        x = F.relu(self.batch2(self.conv2(x)))
        
        x = F.relu(self.conv3(x))
        
        x = F.relu(self.batch3(self.conv4(x)))
        x = F.relu(self.conv5(x))
      
        x = torch.flatten(x, start_dim=1)
        
        x = F.relu(self.linear1(x))

        mu =  self.linear2(x)
        sigma = torch.exp(self.linear3(x))
        
        rand_state = torch.random.get_rng_state()[0]
        torch.random.manual_seed(rand_state+1)
        z = mu + sigma*self.N.sample(mu.shape)


        self.kl=-0.5 * torch.sum(1 + sigma - mu.pow(2) - sigma.exp())
        pz = td.Independent(td.Normal(torch.zeros(d).to(device), torch.ones(d).to(device)),1)
        qz_x = td.Independent(td.Normal(mu, sigma),1) 
        self.kl = td.kl_divergence(qz_x,pz)
        # self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        return qz_x

# %%
class Decoder(nn.Module):
    
    def __init__(self, latent_dims):
        super().__init__()

        self.decoder_lin = nn.Sequential(
            nn.Linear(latent_dims, 128),
            nn.ReLU(True),
            nn.Linear(128, 256*2*2),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(256, 2, 2))

        self.decoder_conv = nn.Sequential(

            nn.ConvTranspose2d(256, 128, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 32, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.ConvTranspose2d(32, 16, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 1, kernel_size, stride, padding=1, output_padding=1),
            nn.Upsample(size=(64,64))
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        
        x = torch.sigmoid(x)
        return x

# %%
class GaussianDecoder(Decoder):
    def forward(self, x):
        x = self.decoder_lin(x)
        
        x = self.unflatten(x)
        x = self.decoder_conv(x)

        x = torch.sigmoid(x)
       
        var = torch.ones_like(x)
        
        return td.Normal(loc=x, scale=var)

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = GaussianDecoder(latent_dims)

    def forward(self, x):
        x = x.to(device)
        qz_x = self.encoder(x)
        
        z = qz_x.rsample()
        return self.decoder(z)

# %%
### Set the random seed for reproducible results


vae = VariationalAutoencoder(latent_dims=d)

lr = 1e-3 

optim = torch.optim.Adam(vae.parameters(), lr=lr, weight_decay=1e-3)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

vae.to(device)
# Out:
# Selected device: cuda
# VariationalAutoencoder(
#   (encoder): VariationalEncoder(
#     (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (batch2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (batch3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (linear1): Linear(in_features=1024, out_features=128, bias=True)
#     (linear2): Linear(in_features=128, out_features=11, bias=True)
#     (linear3): Linear(in_features=128, out_features=11, bias=True)
#   )
#   (decoder): GaussianDecoder(
#     (decoder_lin): Sequential(
#       (0): Linear(in_features=11, out_features=128, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=128, out_features=1024, bias=True)
#       (3): ReLU(inplace=True)
#     )
#     (unflatten): Unflatten(dim=1, unflattened_size=(256, 2, 2))
#     (decoder_conv): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#       (9): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (10): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU(inplace=True)
#       (12): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#       (13): Upsample(size=(64, 64), mode=nearest)
#     )
#   )
# )

# %%
### Training function
def train_epoch(vae, device, dataloader, optimizer):
    # Set train mode for both the encoder and the decoder
    vae.train()
    train_loss = 0.0
    nll_loss = 0.0
    kl_loss = 0.0
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for x in dataloader: 
        # Move tensor to the proper device
        x = x[:,:1,:,:]
       
        x = x.to(device)

        px_z = vae(x)
        
        
        # Evaluate loss
        nll = -px_z.log_prob(x).sum()
        
        kl = vae.encoder.kl.sum()
        
        loss = nll + kl
        
        # loss = ((x - x_hat)**2).sum() + vae.encoder.kl
      
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        # print('\t partial train loss (single batch): %f' % (loss.item()))
        nll_loss += nll.item()
        kl_loss += kl.item()

        train_loss+=loss.item()
        

    return train_loss / len(dataloader.dataset), nll_loss / len(dataloader.dataset), kl_loss / len(dataloader.dataset)

# %%
def test_epoch(vae, device, dataloader):
    # Set evaluation mode for encoder and decoder
    vae.eval()
    val_loss = 0.0
    nll_loss = 0.0
    kl_loss = 0.0
    with torch.no_grad(): # No need to track the gradients
        for x in dataloader:
            # Move tensor to the proper device
            x = x[:,:1,:,:]
            x = x.to(device)

           
            # Encode data
            # encoded_data = vae.encoder(x)
            # decoded_data = vae.decoder(encoded_data)
            # print(decoded_data.size())
            # Decode data
            px_z= vae(x)
        
        
        # Evaluate loss
            nll = -px_z.log_prob(x).sum()

            kl = vae.encoder.kl.sum()

            loss = nll + kl
            
            
            # loss = ((x - x_hat)**2).sum() + vae.encoder.kl
            nll_loss += nll.item()
            kl_loss += kl.item()

          
            val_loss += loss.item()

    return val_loss / len(dataloader.dataset), nll_loss / len(dataloader.dataset), kl_loss / len(dataloader.dataset)

# %%
def plot_ae_outputs(encoder,decoder,n=10,random_seed = random_seed):
    fig, axs = plt.subplots(10, 2,figsize=(30,100))
    # targets = [item[0] for item in test_data]
    # t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    i=0
    random.seed(random_seed)
    for index in random.sample(range(len(val_data)), n):
      img = val_data[index][:1].unsqueeze(0).to(device)
      
      encoder.eval()
      decoder.eval()
      with torch.no_grad():
         rec_img  = decoder(encoder(img).sample()).mean
      axs[i,0].imshow(img.cpu().squeeze().numpy(), cmap='gray')
     
      axs[i,1].imshow(rec_img.cpu().squeeze().numpy(), cmap='gray')
      i=i+1

# %%
num_epochs = 60

train_loss_sum = []
train_nll_sum = []
train_kl_sum = []
val_loss_sum = []
val_nll_sum = []
val_kl_sum = []
for epoch in range(num_epochs):
   train_loss,train_nll_loss,train_kl_loss = train_epoch(vae,device,train_loader,optim)
   val_loss,val_nll_loss,val_kl_loss = test_epoch(vae,device,valid_loader)
   train_loss_sum.append(train_loss)
   train_nll_sum.append(train_nll_loss)
   train_kl_sum.append(train_kl_loss)
   val_loss_sum.append(val_loss)
   val_nll_sum.append(val_nll_loss)
   val_kl_sum.append(val_kl_loss)
   print('\n EPOCH {}/{} \t train loss {:.3f} \t train nll loss {:.3f} \t train kl loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,train_nll_loss,train_kl_loss))
   print('\n val loss {:.3f} \t val nll loss {:.3f} \t val kl loss {:.3f}'.format(val_loss,val_nll_loss,val_kl_loss))
   # plot_ae_outputs(vae.encoder,vae.decoder,n=10)
# Out:
#  EPOCH 1/60 	 train loss 3818.610 	 train nll loss 3815.790 	 train kl loss 2.820
#
#  val loss 3817.122 	 val nll loss 3813.514 	 val kl loss 3.608
#
#  EPOCH 2/60 	 train loss 3814.412 	 train nll loss 3810.328 	 train kl loss 4.084
#
#  val loss 3814.019 	 val nll loss 3809.782 	 val kl loss 4.236
#
#  EPOCH 3/60 	 train loss 3812.440 	 train nll loss 3807.849 	 train kl loss 4.591
#
#  val loss 3812.414 	 val nll loss 3807.928 	 val kl loss 4.485
#
#  EPOCH 4/60 	 train loss 3811.056 	 train nll loss 3806.106 	 train kl loss 4.949
#
#  val loss 3811.437 	 val nll loss 3805.781 	 val kl loss 5.656
#
#  EPOCH 5/60 	 train loss 3809.966 	 train nll loss 3804.623 	 train kl loss 5.343
#
#  val loss 3810.197 	 val nll loss 3804.453 	 val kl loss 5.744
#
#  EPOCH 6/60 	 train loss 3808.790 	 train nll loss 3803.121 	 train kl loss 5.669
#
#  val loss 3808.990 	 val nll loss 3803.010 	 val kl loss 5.981
#
#  EPOCH 7/60 	 train loss 3807.706 	 train nll loss 3801.721 	 train kl loss 5.985
#
#  val loss 3807.718 	 val nll loss 3801.708 	 val kl loss 6.009
#
#  EPOCH 8/60 	 train loss 3806.625 	 train nll loss 3800.513 	 train kl loss 6.112
#
#  val loss 3809.131 	 val nll loss 3802.774 	 val kl loss 6.358
#
#  EPOCH 9/60 	 train loss 3805.917 	 train nll loss 3799.638 	 train kl loss 6.279
#
#  val loss 3806.816 	 val nll loss 3800.321 	 val kl loss 6.494
#
#  EPOCH 10/60 	 train loss 3805.191 	 train nll loss 3798.812 	 train kl loss 6.379
#
#  val loss 3805.775 	 val nll loss 3799.315 	 val kl loss 6.460
#
#  EPOCH 11/60 	 train loss 3804.703 	 train nll loss 3798.244 	 train kl loss 6.459
#
#  val loss 3805.083 	 val nll loss 3798.489 	 val kl loss 6.594
#
#  EPOCH 12/60 	 train loss 3804.092 	 train nll loss 3797.569 	 train kl loss 6.523
#
#  val loss 3805.883 	 val nll loss 3798.737 	 val kl loss 7.146
#
#  EPOCH 13/60 	 train loss 3803.916 	 train nll loss 3797.369 	 train kl loss 6.546
#
#  val loss 3804.321 	 val nll loss 3797.336 	 val kl loss 6.985
#
#  EPOCH 14/60 	 train loss 3803.452 	 train nll loss 3796.836 	 train kl loss 6.616
#
#  val loss 3805.008 	 val nll loss 3798.823 	 val kl loss 6.185
#
#  EPOCH 15/60 	 train loss 3803.063 	 train nll loss 3796.405 	 train kl loss 6.658
#
#  val loss 3804.210 	 val nll loss 3797.375 	 val kl loss 6.835
#
#  EPOCH 16/60 	 train loss 3802.872 	 train nll loss 3796.191 	 train kl loss 6.681
#
#  val loss 3803.134 	 val nll loss 3796.379 	 val kl loss 6.754
#
#  EPOCH 17/60 	 train loss 3802.566 	 train nll loss 3795.828 	 train kl loss 6.738
#
#  val loss 3803.725 	 val nll loss 3796.847 	 val kl loss 6.878
#
#  EPOCH 18/60 	 train loss 3802.385 	 train nll loss 3795.632 	 train kl loss 6.753
#
#  val loss 3803.597 	 val nll loss 3796.790 	 val kl loss 6.807
#
#  EPOCH 19/60 	 train loss 3802.049 	 train nll loss 3795.312 	 train kl loss 6.737
#
#  val loss 3803.091 	 val nll loss 3796.183 	 val kl loss 6.908
#
#  EPOCH 20/60 	 train loss 3801.938 	 train nll loss 3795.177 	 train kl loss 6.761
#
#  val loss 3804.076 	 val nll loss 3797.223 	 val kl loss 6.854
#
#  EPOCH 21/60 	 train loss 3801.778 	 train nll loss 3794.958 	 train kl loss 6.820
#
#  val loss 3803.584 	 val nll loss 3796.226 	 val kl loss 7.359
#
#  EPOCH 22/60 	 train loss 3801.647 	 train nll loss 3794.831 	 train kl loss 6.817
#
#  val loss 3802.695 	 val nll loss 3795.645 	 val kl loss 7.050
#
#  EPOCH 23/60 	 train loss 3801.436 	 train nll loss 3794.599 	 train kl loss 6.837
#
#  val loss 3802.173 	 val nll loss 3795.179 	 val kl loss 6.993
#
#  EPOCH 24/60 	 train loss 3801.288 	 train nll loss 3794.405 	 train kl loss 6.883
#
#  val loss 3802.546 	 val nll loss 3795.599 	 val kl loss 6.947
#
#  EPOCH 25/60 	 train loss 3800.981 	 train nll loss 3794.111 	 train kl loss 6.870
#
#  val loss 3802.655 	 val nll loss 3795.749 	 val kl loss 6.906
#
#  EPOCH 26/60 	 train loss 3800.941 	 train nll loss 3794.028 	 train kl loss 6.913
#
#  val loss 3802.516 	 val nll loss 3795.795 	 val kl loss 6.722
#
#  EPOCH 27/60 	 train loss 3800.887 	 train nll loss 3793.984 	 train kl loss 6.903
#
#  val loss 3803.079 	 val nll loss 3795.910 	 val kl loss 7.169
#
#  EPOCH 28/60 	 train loss 3800.539 	 train nll loss 3793.588 	 train kl loss 6.951
#
#  val loss 3802.645 	 val nll loss 3795.626 	 val kl loss 7.019
#
#  EPOCH 29/60 	 train loss 3800.396 	 train nll loss 3793.405 	 train kl loss 6.991
#
#  val loss 3802.638 	 val nll loss 3795.403 	 val kl loss 7.235
#
#  EPOCH 30/60 	 train loss 3800.442 	 train nll loss 3793.389 	 train kl loss 7.053
#
#  val loss 3802.411 	 val nll loss 3795.267 	 val kl loss 7.144
#
#  EPOCH 31/60 	 train loss 3800.031 	 train nll loss 3792.963 	 train kl loss 7.068
#
#  val loss 3801.954 	 val nll loss 3794.754 	 val kl loss 7.200
#
#  EPOCH 32/60 	 train loss 3799.921 	 train nll loss 3792.833 	 train kl loss 7.088
#
#  val loss 3802.135 	 val nll loss 3794.472 	 val kl loss 7.663
#
#  EPOCH 33/60 	 train loss 3799.787 	 train nll loss 3792.660 	 train kl loss 7.127
#
#  val loss 3802.035 	 val nll loss 3794.665 	 val kl loss 7.370
#
#  EPOCH 34/60 	 train loss 3799.652 	 train nll loss 3792.463 	 train kl loss 7.189
#
#  val loss 3800.808 	 val nll loss 3793.402 	 val kl loss 7.406
#
#  EPOCH 35/60 	 train loss 3799.412 	 train nll loss 3792.231 	 train kl loss 7.180
#
#  val loss 3801.248 	 val nll loss 3793.616 	 val kl loss 7.632
#
#  EPOCH 36/60 	 train loss 3799.253 	 train nll loss 3792.056 	 train kl loss 7.197
#
#  val loss 3801.183 	 val nll loss 3793.722 	 val kl loss 7.461
#
#  EPOCH 37/60 	 train loss 3799.190 	 train nll loss 3791.979 	 train kl loss 7.210
#
#  val loss 3800.883 	 val nll loss 3793.874 	 val kl loss 7.009
#
#  EPOCH 38/60 	 train loss 3798.901 	 train nll loss 3791.661 	 train kl loss 7.240
#
#  val loss 3801.942 	 val nll loss 3794.665 	 val kl loss 7.277
#
#  EPOCH 39/60 	 train loss 3798.740 	 train nll loss 3791.434 	 train kl loss 7.306
#
#  val loss 3800.141 	 val nll loss 3792.919 	 val kl loss 7.221
#
#  EPOCH 40/60 	 train loss 3798.528 	 train nll loss 3791.251 	 train kl loss 7.277
#
#  val loss 3800.660 	 val nll loss 3793.205 	 val kl loss 7.455
#
#  EPOCH 41/60 	 train loss 3798.428 	 train nll loss 3791.069 	 train kl loss 7.359
#
#  val loss 3800.050 	 val nll loss 3792.576 	 val kl loss 7.474
#
#  EPOCH 42/60 	 train loss 3798.310 	 train nll loss 3790.959 	 train kl loss 7.351
#
#  val loss 3800.212 	 val nll loss 3793.154 	 val kl loss 7.058
#
#  EPOCH 43/60 	 train loss 3798.041 	 train nll loss 3790.646 	 train kl loss 7.395
#
#  val loss 3800.170 	 val nll loss 3792.633 	 val kl loss 7.537
#
#  EPOCH 44/60 	 train loss 3797.854 	 train nll loss 3790.404 	 train kl loss 7.450
#
#  val loss 3800.806 	 val nll loss 3793.315 	 val kl loss 7.491
#
#  EPOCH 45/60 	 train loss 3797.710 	 train nll loss 3790.284 	 train kl loss 7.427
#
#  val loss 3800.232 	 val nll loss 3792.695 	 val kl loss 7.537
#
#  EPOCH 46/60 	 train loss 3797.631 	 train nll loss 3790.142 	 train kl loss 7.489
#
#  val loss 3800.467 	 val nll loss 3792.933 	 val kl loss 7.534
#
#  EPOCH 47/60 	 train loss 3797.423 	 train nll loss 3789.898 	 train kl loss 7.525
#
#  val loss 3800.009 	 val nll loss 3792.321 	 val kl loss 7.688
#
#  EPOCH 48/60 	 train loss 3797.282 	 train nll loss 3789.715 	 train kl loss 7.567
#
#  val loss 3799.307 	 val nll loss 3791.590 	 val kl loss 7.717
#
#  EPOCH 49/60 	 train loss 3797.107 	 train nll loss 3789.554 	 train kl loss 7.554
#
#  val loss 3799.194 	 val nll loss 3791.591 	 val kl loss 7.603
#
#  EPOCH 50/60 	 train loss 3796.822 	 train nll loss 3789.250 	 train kl loss 7.572
#
#  val loss 3799.908 	 val nll loss 3792.376 	 val kl loss 7.532
#
#  EPOCH 51/60 	 train loss 3796.758 	 train nll loss 3789.128 	 train kl loss 7.630
#
#  val loss 3799.242 	 val nll loss 3791.809 	 val kl loss 7.433
#
#  EPOCH 52/60 	 train loss 3796.515 	 train nll loss 3788.934 	 train kl loss 7.580
#
#  val loss 3799.370 	 val nll loss 3791.767 	 val kl loss 7.603
#
#  EPOCH 53/60 	 train loss 3796.635 	 train nll loss 3788.954 	 train kl loss 7.681
#
#  val loss 3799.421 	 val nll loss 3791.669 	 val kl loss 7.752
#
#  EPOCH 54/60 	 train loss 3796.323 	 train nll loss 3788.679 	 train kl loss 7.643
#
#  val loss 3798.801 	 val nll loss 3791.376 	 val kl loss 7.425
#
#  EPOCH 55/60 	 train loss 3796.276 	 train nll loss 3788.600 	 train kl loss 7.676
#
#  val loss 3798.777 	 val nll loss 3790.949 	 val kl loss 7.829
#
#  EPOCH 56/60 	 train loss 3796.205 	 train nll loss 3788.492 	 train kl loss 7.713
#
#  val loss 3798.601 	 val nll loss 3790.643 	 val kl loss 7.958
#
#  EPOCH 57/60 	 train loss 3796.023 	 train nll loss 3788.293 	 train kl loss 7.729
#
#  val loss 3799.484 	 val nll loss 3791.841 	 val kl loss 7.643
#
#  EPOCH 58/60 	 train loss 3796.052 	 train nll loss 3788.319 	 train kl loss 7.733
#
#  val loss 3798.918 	 val nll loss 3790.971 	 val kl loss 7.947
#
#  EPOCH 59/60 	 train loss 3795.875 	 train nll loss 3788.159 	 train kl loss 7.716
#
#  val loss 3798.054 	 val nll loss 3790.219 	 val kl loss 7.835
#
#  EPOCH 60/60 	 train loss 3795.672 	 train nll loss 3787.939 	 train kl loss 7.733
#
#  val loss 3798.785 	 val nll loss 3791.003 	 val kl loss 7.781

# %%
plot_ae_outputs(vae.encoder,vae.decoder,n=10,random_seed = 11)

# %%
fig, axs = plt.subplots(1, 3,figsize=(20,5))

axs[0].plot(train_loss_sum, label="train")
axs[0].plot(val_loss_sum,label = "val")
axs[0].legend()
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Loss")
axs[1].plot(train_nll_sum, label="train")
axs[1].plot(val_nll_sum,label = "val")
axs[1].legend()
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Nll Loss")
axs[2].plot(train_kl_sum, label="train")
axs[2].plot(val_kl_sum,label = "val")
axs[2].legend()
axs[2].set_xlabel("Epochs")
axs[2].set_ylabel("Kl Loss")

# %%
def ssim(img1, img2):
    C1 = (0.01 * 1)**2
    C2 = (0.03 * 1)**2

    # img1 = img1.astype(np.float64)
    # img2 = img2.astype(np.float64)
    kernel = cv2.getGaussianKernel(11, 1.5)
    window = np.outer(kernel, kernel.transpose())

    mu1 = cv2.filter2D(img1, -1, window)[5:-5, 5:-5]  # valid
    mu2 = cv2.filter2D(img2, -1, window)[5:-5, 5:-5]
    mu1_sq = mu1**2
    mu2_sq = mu2**2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = cv2.filter2D(img1**2, -1, window)[5:-5, 5:-5] - mu1_sq
    sigma2_sq = cv2.filter2D(img2**2, -1, window)[5:-5, 5:-5] - mu2_sq
    sigma12 = cv2.filter2D(img1 * img2, -1, window)[5:-5, 5:-5] - mu1_mu2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) *
                                                            (sigma1_sq + sigma2_sq + C2))
    return ssim_map.mean()


def calculate_ssim(img1, img2):
    '''calculate SSIM
    the same outputs as MATLAB's
    img1, img2: [0, 255]
    '''
    if not img1.shape == img2.shape:
        raise ValueError('Input images must have the same dimensions.')
    if img1.ndim == 2:
        return ssim(img1, img2)
    elif img1.ndim == 3:
        if img1.shape[2] == 3:
            ssims = []
            for i in range(3):
                ssims.append(ssim(img1, img2))
            return np.array(ssims).mean()
        elif img1.shape[2] == 1:
            return ssim(np.squeeze(img1), np.squeeze(img2))
    else:
        raise ValueError('Wrong input image dimensions.')

# %%
seqlen=10
test_predict_loss = 0.0
test_impu_loss = 0.0
test_impu_part_loss = 0.0
impuated_data_sum = 0
test_psnr = 0
test_ssim =0
input_dataset = val_data
compare_dataset = full_val_data
with torch.no_grad():

    for i in range(len(input_dataset)):
        
        x = input_dataset[i][:1]
      
        y = compare_dataset[i].squeeze()

        input_image = x.unsqueeze(0)
  
        predict_image = vae.decoder(vae.encoder(input_image)).mean.squeeze().cpu()

        image_mask = input_dataset[i][1:].squeeze()
        impuated_data_sum+=(image_mask.flatten()==0).sum().item()
        imputed_part = predict_image*(1-image_mask)
        full_part = y*(1-image_mask)

        
        loss_p = (abs(predict_image - y)/(predict_image.size(0)*predict_image.size(1))).sum()
        loss_ip = (abs(imputed_part - full_part)).sum()
        mse= (((predict_image - y)**2)/(predict_image.size(0)*predict_image.size(1))).sum()
        
        
        psnr = 20*math.log10(1/math.sqrt(mse))
        test_psnr += psnr
       
        test_predict_loss += loss_p.item()
       
        test_impu_part_loss += loss_ip.item()
        ssim_p = ssim(predict_image.cpu().detach().numpy(),y.cpu().detach().numpy())
        test_ssim +=ssim_p
       


print(test_predict_loss / len(input_dataset))
print(test_impu_part_loss / impuated_data_sum)
print(test_psnr / len(input_dataset))
print(test_ssim / len(input_dataset))
