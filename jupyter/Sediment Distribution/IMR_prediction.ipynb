# %%
import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd 
import random 
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split, Dataset
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import math
import cv2
import torch.distributions as td

# %%
random_seed = 111

# %%
origin_dataset = torch.load('w_full_dataset.pt')

# %%
m=len(origin_dataset)
train_data, val_data, test_data = origin_dataset[:int(m*0.6)], origin_dataset[int(m*0.6):int(m*0.8)],origin_dataset[int(m*0.8):]

batch_size=80
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size)

# %%
class VariationalEncoder(nn.Module):
    def __init__(self, latent_dims):  
        super(VariationalEncoder, self).__init__()

        self.conv1 = nn.Conv2d(1, 16, kernel_size, stride, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size, stride, padding=1)
        self.batch2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 64, kernel_size, stride, padding=1)  
        self.conv4 = nn.Conv2d(64, 128, kernel_size, stride, padding=1)
        self.batch3 = nn.BatchNorm2d(128)
        self.conv5 = nn.Conv2d(128, 256, kernel_size, stride, padding=1)
        self.linear1 = nn.Linear(256*3*5, 128)
        self.linear2 = nn.Linear(128, latent_dims)
        self.linear3 = nn.Linear(128, latent_dims)

        self.N = td.Normal(0, 1)
        self.N.loc = self.N.loc.cuda() # hack to get sampling on the GPU
        self.N.scale = self.N.scale.cuda()
        self.kl = 0
        
    def forward(self, x):
        x = x.to(device)


        x = F.relu(self.conv1(x))
        x = F.relu(self.batch2(self.conv2(x)))
        
        x = F.relu(self.conv3(x))
        
        x = F.relu(self.batch3(self.conv4(x)))
        x = F.relu(self.conv5(x))
      
        x = torch.flatten(x, start_dim=1)
        
        x = F.relu(self.linear1(x))

        mu =  self.linear2(x)
        log_var = self.linear3(x)
        sigma = torch.exp(0.5 * log_var)
        
        rand_state = torch.random.get_rng_state()[0]
        torch.random.manual_seed(rand_state+1)
        z = mu + sigma*self.N.sample(mu.shape)
        self.kl=-0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp(),dim=1)
        # self.kl = (sigma**2 + mu**2 - torch.log(sigma) - 1/2).sum()
        return z

# %%
class Decoder(nn.Module):
    
    def __init__(self, latent_dims):
        super().__init__()

        self.decoder_lin = nn.Sequential(
            nn.Linear(latent_dims, 128),
            nn.ReLU(True),
            nn.Linear(128, 256*3*5),
            nn.ReLU(True)
        )

        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(256, 3, 5))

        self.decoder_conv = nn.Sequential(

            nn.ConvTranspose2d(256, 128, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            nn.ConvTranspose2d(128, 64, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.ConvTranspose2d(64, 32, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.ConvTranspose2d(32, 16, kernel_size, stride, padding=1, output_padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            nn.ConvTranspose2d(16, 1, kernel_size, stride, padding=1, output_padding=1),
            nn.Upsample(size=(96,135))
        )
        
    def forward(self, x):
        x = self.decoder_lin(x)
        
        x = self.unflatten(x)
        x = self.decoder_conv(x)
        
        x = torch.sigmoid(x)
        return x

# %%
class GaussianDecoder(Decoder):
    def forward(self, x):
        x = self.decoder_lin(x)
        
        x = self.unflatten(x)
        x = self.decoder_conv(x)

        x = torch.sigmoid(x)
       
        var = torch.ones_like(x)
        
        return td.Normal(loc=x, scale=var)

# %%
class VariationalAutoencoder(nn.Module):
    def __init__(self, latent_dims):
        super(VariationalAutoencoder, self).__init__()
        self.encoder = VariationalEncoder(latent_dims)
        self.decoder = GaussianDecoder(latent_dims)

    def forward(self, x):
        x = x.to(device)
        z = self.encoder(x)
        return self.decoder(z)

# %%
### Set the random seed for reproducible results
torch.manual_seed(random_seed)

kernel_size = [3,3]
stride=[2,2]

d = 30

vae = VariationalAutoencoder(latent_dims=d)

lr = 1e-3 

optim = torch.optim.Adam(vae.parameters(), lr=lr, weight_decay=1e-5)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

vae.to(device)


criterion = nn.BCELoss(reduction='sum')
# Out:
# Selected device: cuda

# %%
def train_epoch(vae, device, dataloader, optimizer):
    # Set train mode for both the encoder and the decoder
    vae.train()
    train_loss = 0.0
    nll_loss = 0.0
    kl_loss = 0.0
    # Iterate the dataloader (we do not need the label values, this is unsupervised learning)
    for data in dataloader: 
        # Move tensor to the proper device
   
        x = data.to(device)
       
        x_hat = vae(x).mean
        
        # Evaluate loss
        # if all zero in a mask, change back to 1
       

    
      

        nll = ((x_hat-x)**2).sum()

        kl = vae.encoder.kl.mean()

        loss = nll + kl*0.1
        # loss = ((x - x_hat)**2).sum() + vae.encoder.kl
      
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Print batch loss
        # print('\t partial train loss (single batch): %f' % (loss.item()))
        nll_loss += nll.item()
        kl_loss += kl.item()

        train_loss+=loss.item()
        

    return train_loss / len(dataloader), nll_loss / len(dataloader), kl_loss / len(dataloader)

# %%
def test_epoch(vae, device, dataloader):
    # Set evaluation mode for encoder and decoder
    vae.eval()
    val_loss = 0.0
    nll_loss = 0.0
    kl_loss = 0.0
    bce_loss = 0.0
    with torch.no_grad(): # No need to track the gradients
        for data in dataloader:
            # Move tensor to the proper device
           
            x = data.to(device)
           
            x_hat = vae(x).mean
        


            # temp_mask = mask.squeeze().flatten(1,2)
            # mask_sum = temp_mask.sum(1)
            # boolen_mask = (mask_sum ==0)
            # temp_mask[boolen_mask] = 1
            # temp_mask = temp_mask.reshape(mask.shape)
           
            # Encode data
            # encoded_data = vae.encoder(x)
            # decoded_data = vae.decoder(encoded_data)
            # print(decoded_data.size())
            # Decode data
            
        # Evaluate loss
            
            nll = ((x_hat-x)**2).sum()

            kl = vae.encoder.kl.mean()

            loss = nll + kl*0.1
            
            
            # loss = ((x - x_hat)**2).sum() + vae.encoder.kl
            nll_loss += nll.item()
            kl_loss += kl.item()

          
            val_loss += loss.item()
    return val_loss / len(dataloader), nll_loss / len(dataloader), kl_loss / len(dataloader)

# %%
def plot_ae_outputs(encoder,decoder,n=10):
    fig, axs = plt.subplots(10, 2,figsize=(30,100))
    # targets = [item[0] for item in test_data]
    # t_idx = {i:np.where(targets==i)[0][0] for i in range(n)}
    i=0
    random.seed(random_seed)
    for index in random.sample(range(len(test_data)), n):
      img = test_data[index][:1].unsqueeze(0).to(device)
      
      encoder.eval()
      decoder.eval()
      with torch.no_grad():
         rec_img  = decoder(encoder(img)).mean
      axs[i,0].imshow(img.cpu().squeeze().numpy(), cmap='jet')
     
      axs[i,1].imshow(rec_img.cpu().squeeze().numpy(), cmap='jet')
      i=i+1

# %%
num_epochs = 100
for epoch in range(num_epochs):
   train_loss,train_nll_loss,train_kl_loss = train_epoch(vae,device,train_loader,optim)
   val_loss,val_nll_loss,val_kl_loss= test_epoch(vae,device,valid_loader)

   print('\n  EPOCH {}/{} \t train loss {:.3f} \t train nll loss {:.3f} \t train kl loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,train_nll_loss,train_kl_loss))
   print('\n val loss {:.3f} \t val nll loss {:.3f} \t val kl loss {:.3f}'.format(val_loss,val_nll_loss,val_kl_loss))
# Out:
#   EPOCH 1/100 	 train loss 158249.586 	 train nll loss 109018.572 	 train kl loss 492310.114
#
#  val loss 65646.534 	 val nll loss 65637.791 	 val kl loss 87.424
#
#   EPOCH 2/100 	 train loss 51164.444 	 train nll loss 51157.218 	 train kl loss 72.263
#
#  val loss 33778.344 	 val nll loss 33766.676 	 val kl loss 116.677
#
#   EPOCH 3/100 	 train loss 26526.353 	 train nll loss 26515.386 	 train kl loss 109.671
#
#  val loss 18094.219 	 val nll loss 18080.234 	 val kl loss 139.850
#
#   EPOCH 4/100 	 train loss 15692.925 	 train nll loss 15681.026 	 train kl loss 118.998
#
#  val loss 11869.209 	 val nll loss 11857.469 	 val kl loss 117.403
#
#   EPOCH 5/100 	 train loss 10959.113 	 train nll loss 10948.589 	 train kl loss 105.241
#
#  val loss 9482.209 	 val nll loss 9471.107 	 val kl loss 111.017
#
#   EPOCH 6/100 	 train loss 8530.049 	 train nll loss 8518.056 	 train kl loss 119.932
#
#  val loss 6991.455 	 val nll loss 6980.951 	 val kl loss 105.033
#
#   EPOCH 7/100 	 train loss 7242.287 	 train nll loss 7228.964 	 train kl loss 133.227
#
#  val loss 6920.097 	 val nll loss 6908.131 	 val kl loss 119.663
#
#   EPOCH 8/100 	 train loss 6321.299 	 train nll loss 6306.161 	 train kl loss 151.379
#
#  val loss 6328.451 	 val nll loss 6315.743 	 val kl loss 127.082
#
#   EPOCH 9/100 	 train loss 5565.615 	 train nll loss 5550.616 	 train kl loss 149.995
#
#  val loss 5616.256 	 val nll loss 5603.654 	 val kl loss 126.014
#
#   EPOCH 10/100 	 train loss 5077.150 	 train nll loss 5062.039 	 train kl loss 151.113
#
#  val loss 5340.031 	 val nll loss 5328.063 	 val kl loss 119.678
#
#   EPOCH 11/100 	 train loss 4848.508 	 train nll loss 4833.656 	 train kl loss 148.528
#
#  val loss 5180.125 	 val nll loss 5168.147 	 val kl loss 119.777
#
#   EPOCH 12/100 	 train loss 4574.476 	 train nll loss 4559.589 	 train kl loss 148.869
#
#  val loss 5159.435 	 val nll loss 5146.466 	 val kl loss 129.684
#
#   EPOCH 13/100 	 train loss 4445.444 	 train nll loss 4431.070 	 train kl loss 143.743
#
#  val loss 5239.453 	 val nll loss 5226.473 	 val kl loss 129.796
#
#   EPOCH 14/100 	 train loss 4686.540 	 train nll loss 4671.398 	 train kl loss 151.423
#
#  val loss 5645.757 	 val nll loss 5632.339 	 val kl loss 134.186
#
#   EPOCH 15/100 	 train loss 4425.365 	 train nll loss 4409.161 	 train kl loss 162.046
#
#  val loss 4576.001 	 val nll loss 4561.427 	 val kl loss 145.738
#
#   EPOCH 16/100 	 train loss 4024.085 	 train nll loss 4006.849 	 train kl loss 172.355
#
#  val loss 4363.036 	 val nll loss 4348.957 	 val kl loss 140.786
#
#   EPOCH 17/100 	 train loss 3751.690 	 train nll loss 3734.724 	 train kl loss 169.658
#
#  val loss 4292.929 	 val nll loss 4279.398 	 val kl loss 135.313
#
#   EPOCH 18/100 	 train loss 3562.871 	 train nll loss 3546.349 	 train kl loss 165.222
#
#  val loss 4270.620 	 val nll loss 4257.214 	 val kl loss 134.053
#
#   EPOCH 19/100 	 train loss 3426.181 	 train nll loss 3410.139 	 train kl loss 160.415
#
#  val loss 4184.755 	 val nll loss 4171.717 	 val kl loss 130.388
#
#   EPOCH 20/100 	 train loss 3299.921 	 train nll loss 3284.315 	 train kl loss 156.062
#
#  val loss 4072.763 	 val nll loss 4059.626 	 val kl loss 131.367
#
#   EPOCH 21/100 	 train loss 3207.446 	 train nll loss 3192.028 	 train kl loss 154.181
#
#  val loss 4216.849 	 val nll loss 4203.923 	 val kl loss 129.254
#
#   EPOCH 22/100 	 train loss 3130.476 	 train nll loss 3115.142 	 train kl loss 153.347
#
#  val loss 4119.090 	 val nll loss 4106.151 	 val kl loss 129.395
#
#   EPOCH 23/100 	 train loss 3162.228 	 train nll loss 3147.186 	 train kl loss 150.411
#
#  val loss 4787.329 	 val nll loss 4774.181 	 val kl loss 131.482
#
#   EPOCH 24/100 	 train loss 3394.638 	 train nll loss 3379.562 	 train kl loss 150.762
#
#  val loss 4527.955 	 val nll loss 4514.665 	 val kl loss 132.900
#
#   EPOCH 25/100 	 train loss 3704.891 	 train nll loss 3689.016 	 train kl loss 158.745
#
#  val loss 4662.236 	 val nll loss 4648.267 	 val kl loss 139.689
#
#   EPOCH 26/100 	 train loss 3604.704 	 train nll loss 3588.359 	 train kl loss 163.456
#
#  val loss 4381.291 	 val nll loss 4368.962 	 val kl loss 123.289
#
#   EPOCH 27/100 	 train loss 3387.306 	 train nll loss 3370.855 	 train kl loss 164.513
#
#  val loss 4023.311 	 val nll loss 4009.198 	 val kl loss 141.131
#
#   EPOCH 28/100 	 train loss 3267.154 	 train nll loss 3249.915 	 train kl loss 172.398
#
#  val loss 4014.987 	 val nll loss 4001.716 	 val kl loss 132.713
#
#   EPOCH 29/100 	 train loss 3125.734 	 train nll loss 3107.721 	 train kl loss 180.128
#
#  val loss 4040.379 	 val nll loss 4026.194 	 val kl loss 141.855
#
#   EPOCH 30/100 	 train loss 2889.049 	 train nll loss 2871.734 	 train kl loss 173.153
#
#  val loss 4186.895 	 val nll loss 4171.740 	 val kl loss 151.552
#
#   EPOCH 31/100 	 train loss 2774.699 	 train nll loss 2757.266 	 train kl loss 174.328
#
#  val loss 3754.443 	 val nll loss 3739.646 	 val kl loss 147.974
#
#   EPOCH 32/100 	 train loss 2747.112 	 train nll loss 2730.281 	 train kl loss 168.309
#
#  val loss 3802.518 	 val nll loss 3788.448 	 val kl loss 140.700
#
#   EPOCH 33/100 	 train loss 2758.517 	 train nll loss 2741.366 	 train kl loss 171.506
#
#  val loss 3977.176 	 val nll loss 3963.741 	 val kl loss 134.351
#
#   EPOCH 34/100 	 train loss 2666.750 	 train nll loss 2649.784 	 train kl loss 169.663
#
#  val loss 4006.720 	 val nll loss 3992.535 	 val kl loss 141.849
#
#   EPOCH 35/100 	 train loss 2639.387 	 train nll loss 2622.568 	 train kl loss 168.188
#
#  val loss 3856.335 	 val nll loss 3841.285 	 val kl loss 150.497
#
#   EPOCH 36/100 	 train loss 2619.614 	 train nll loss 2603.310 	 train kl loss 163.043
#
#  val loss 3903.105 	 val nll loss 3888.456 	 val kl loss 146.492
#
#   EPOCH 37/100 	 train loss 2662.041 	 train nll loss 2644.982 	 train kl loss 170.590
#
#  val loss 4152.293 	 val nll loss 4137.374 	 val kl loss 149.192
#
#   EPOCH 38/100 	 train loss 2760.189 	 train nll loss 2742.977 	 train kl loss 172.129
#
#  val loss 4033.296 	 val nll loss 4019.295 	 val kl loss 140.015
#
#   EPOCH 39/100 	 train loss 2728.789 	 train nll loss 2711.411 	 train kl loss 173.781
#
#  val loss 4046.310 	 val nll loss 4033.178 	 val kl loss 131.318
#
#   EPOCH 40/100 	 train loss 2725.306 	 train nll loss 2708.164 	 train kl loss 171.419
#
#  val loss 4622.956 	 val nll loss 4609.795 	 val kl loss 131.608
#
#   EPOCH 41/100 	 train loss 2856.958 	 train nll loss 2840.324 	 train kl loss 166.336
#
#  val loss 5954.016 	 val nll loss 5939.261 	 val kl loss 147.554
#
#   EPOCH 42/100 	 train loss 3602.618 	 train nll loss 3583.023 	 train kl loss 195.952
#
#  val loss 4363.468 	 val nll loss 4344.076 	 val kl loss 193.926
#
#   EPOCH 43/100 	 train loss 3152.795 	 train nll loss 3130.961 	 train kl loss 218.348
#
#  val loss 3798.963 	 val nll loss 3780.445 	 val kl loss 185.180
#
#   EPOCH 44/100 	 train loss 2489.595 	 train nll loss 2468.239 	 train kl loss 213.552
#
#  val loss 3684.033 	 val nll loss 3666.200 	 val kl loss 178.334
#
#   EPOCH 45/100 	 train loss 2209.641 	 train nll loss 2189.026 	 train kl loss 206.148
#
#  val loss 3649.730 	 val nll loss 3632.012 	 val kl loss 177.178
#
#   EPOCH 46/100 	 train loss 2092.945 	 train nll loss 2072.701 	 train kl loss 202.433
#
#  val loss 3655.957 	 val nll loss 3638.710 	 val kl loss 172.477
#
#   EPOCH 47/100 	 train loss 2036.472 	 train nll loss 2016.919 	 train kl loss 195.527
#
#  val loss 3656.390 	 val nll loss 3639.855 	 val kl loss 165.349
#
#   EPOCH 48/100 	 train loss 1997.859 	 train nll loss 1979.170 	 train kl loss 186.895
#
#  val loss 3612.062 	 val nll loss 3596.016 	 val kl loss 160.459
#
#   EPOCH 49/100 	 train loss 1983.913 	 train nll loss 1965.742 	 train kl loss 181.711
#
#  val loss 3678.918 	 val nll loss 3662.900 	 val kl loss 160.188
#
#   EPOCH 50/100 	 train loss 1988.729 	 train nll loss 1971.004 	 train kl loss 177.257
#
#  val loss 3856.353 	 val nll loss 3839.531 	 val kl loss 168.220
#
#   EPOCH 51/100 	 train loss 2026.126 	 train nll loss 2008.451 	 train kl loss 176.749
#
#  val loss 4198.760 	 val nll loss 4181.768 	 val kl loss 169.922
#
#   EPOCH 52/100 	 train loss 2161.941 	 train nll loss 2143.776 	 train kl loss 181.652
#
#  val loss 4294.509 	 val nll loss 4277.322 	 val kl loss 171.871
#
#   EPOCH 53/100 	 train loss 2479.764 	 train nll loss 2460.811 	 train kl loss 189.528
#
#  val loss 3707.157 	 val nll loss 3690.501 	 val kl loss 166.568
#
#   EPOCH 54/100 	 train loss 2595.507 	 train nll loss 2575.677 	 train kl loss 198.295
#
#  val loss 3944.605 	 val nll loss 3927.657 	 val kl loss 169.483
#
#   EPOCH 55/100 	 train loss 2434.995 	 train nll loss 2414.967 	 train kl loss 200.276
#
#  val loss 4113.109 	 val nll loss 4095.677 	 val kl loss 174.326
#
#   EPOCH 56/100 	 train loss 2564.393 	 train nll loss 2542.805 	 train kl loss 215.884
#
#  val loss 3794.285 	 val nll loss 3773.027 	 val kl loss 212.581
#
#   EPOCH 57/100 	 train loss 2274.464 	 train nll loss 2252.408 	 train kl loss 220.560
#
#  val loss 3842.001 	 val nll loss 3823.259 	 val kl loss 187.416
#
#   EPOCH 58/100 	 train loss 2120.074 	 train nll loss 2099.072 	 train kl loss 210.013
#
#  val loss 3706.394 	 val nll loss 3686.987 	 val kl loss 194.075
#
#   EPOCH 59/100 	 train loss 1955.454 	 train nll loss 1934.054 	 train kl loss 214.000
#
#  val loss 3722.134 	 val nll loss 3704.075 	 val kl loss 180.595
#
#   EPOCH 60/100 	 train loss 1893.163 	 train nll loss 1872.003 	 train kl loss 211.606
#
#  val loss 4059.483 	 val nll loss 4041.580 	 val kl loss 179.028
#
#   EPOCH 61/100 	 train loss 1897.977 	 train nll loss 1877.243 	 train kl loss 207.337
#
#  val loss 3830.042 	 val nll loss 3811.840 	 val kl loss 182.022
#
#   EPOCH 62/100 	 train loss 1869.418 	 train nll loss 1849.354 	 train kl loss 200.637
#
#  val loss 3915.896 	 val nll loss 3897.313 	 val kl loss 185.830
#
#   EPOCH 63/100 	 train loss 1873.742 	 train nll loss 1854.309 	 train kl loss 194.334
#
#  val loss 3835.979 	 val nll loss 3817.963 	 val kl loss 180.154
#
#   EPOCH 64/100 	 train loss 1959.316 	 train nll loss 1939.519 	 train kl loss 197.969
#
#  val loss 3663.878 	 val nll loss 3645.996 	 val kl loss 178.814
#
#   EPOCH 65/100 	 train loss 1963.426 	 train nll loss 1943.432 	 train kl loss 199.935
#
#  val loss 3843.827 	 val nll loss 3826.796 	 val kl loss 170.307
#
#   EPOCH 66/100 	 train loss 2015.139 	 train nll loss 1995.298 	 train kl loss 198.406
#
#  val loss 3921.660 	 val nll loss 3903.713 	 val kl loss 179.474
#
#   EPOCH 67/100 	 train loss 1906.944 	 train nll loss 1886.679 	 train kl loss 202.647
#
#  val loss 4565.108 	 val nll loss 4545.398 	 val kl loss 197.097
#
#   EPOCH 68/100 	 train loss 1903.258 	 train nll loss 1883.305 	 train kl loss 199.536
#
#  val loss 4235.623 	 val nll loss 4215.779 	 val kl loss 198.445
#
#   EPOCH 69/100 	 train loss 2046.019 	 train nll loss 2024.906 	 train kl loss 211.137
#
#  val loss 3960.884 	 val nll loss 3941.142 	 val kl loss 197.419
#
#   EPOCH 70/100 	 train loss 1974.371 	 train nll loss 1953.660 	 train kl loss 207.113
#
#  val loss 3799.750 	 val nll loss 3782.334 	 val kl loss 174.151
#
#   EPOCH 71/100 	 train loss 2035.482 	 train nll loss 2014.853 	 train kl loss 206.291
#
#  val loss 4255.957 	 val nll loss 4237.275 	 val kl loss 186.816
#
#   EPOCH 72/100 	 train loss 1947.248 	 train nll loss 1925.896 	 train kl loss 213.527
#
#  val loss 4480.478 	 val nll loss 4460.565 	 val kl loss 199.123
#
#   EPOCH 73/100 	 train loss 1970.566 	 train nll loss 1949.546 	 train kl loss 210.197
#
#  val loss 4004.772 	 val nll loss 3985.977 	 val kl loss 187.954
#
#   EPOCH 74/100 	 train loss 2073.157 	 train nll loss 2051.734 	 train kl loss 214.237
#
#  val loss 4128.096 	 val nll loss 4108.528 	 val kl loss 195.681
#
#   EPOCH 75/100 	 train loss 2179.428 	 train nll loss 2159.329 	 train kl loss 200.987
#
#  val loss 4210.543 	 val nll loss 4194.488 	 val kl loss 160.547
#
#   EPOCH 76/100 	 train loss 2323.401 	 train nll loss 2301.049 	 train kl loss 223.518
#
#  val loss 4061.714 	 val nll loss 4044.059 	 val kl loss 176.558
#
#   EPOCH 77/100 	 train loss 2371.408 	 train nll loss 2348.889 	 train kl loss 225.190
#
#  val loss 4164.124 	 val nll loss 4140.026 	 val kl loss 240.975
#
#   EPOCH 78/100 	 train loss 2196.882 	 train nll loss 2172.490 	 train kl loss 243.927
#
#  val loss 3916.809 	 val nll loss 3892.624 	 val kl loss 241.857
#
#   EPOCH 79/100 	 train loss 2152.576 	 train nll loss 2127.616 	 train kl loss 249.600
#
#  val loss 4304.439 	 val nll loss 4282.036 	 val kl loss 224.028
#
#   EPOCH 80/100 	 train loss 2235.182 	 train nll loss 2210.561 	 train kl loss 246.213
#
#  val loss 4429.269 	 val nll loss 4410.782 	 val kl loss 184.880
#
#   EPOCH 81/100 	 train loss 2182.302 	 train nll loss 2157.897 	 train kl loss 244.048
#
#  val loss 4428.098 	 val nll loss 4405.493 	 val kl loss 226.051
#
#   EPOCH 82/100 	 train loss 2189.968 	 train nll loss 2164.261 	 train kl loss 257.064
#
#  val loss 3845.965 	 val nll loss 3822.379 	 val kl loss 235.855
#
#   EPOCH 83/100 	 train loss 1972.978 	 train nll loss 1947.172 	 train kl loss 258.060
#
#  val loss 3786.013 	 val nll loss 3765.133 	 val kl loss 208.803
#
#   EPOCH 84/100 	 train loss 1813.060 	 train nll loss 1788.700 	 train kl loss 243.591
#
#  val loss 3846.608 	 val nll loss 3825.421 	 val kl loss 211.870
#
#   EPOCH 85/100 	 train loss 1675.061 	 train nll loss 1651.564 	 train kl loss 234.969
#
#  val loss 4046.853 	 val nll loss 4025.284 	 val kl loss 215.690
#
#   EPOCH 86/100 	 train loss 1604.368 	 train nll loss 1581.264 	 train kl loss 231.036
#
#  val loss 3962.625 	 val nll loss 3940.781 	 val kl loss 218.445
#
#   EPOCH 87/100 	 train loss 1575.604 	 train nll loss 1552.599 	 train kl loss 230.050
#
#  val loss 3825.568 	 val nll loss 3804.097 	 val kl loss 214.713
#
#   EPOCH 88/100 	 train loss 1594.217 	 train nll loss 1571.328 	 train kl loss 228.895
#
#  val loss 3824.040 	 val nll loss 3802.625 	 val kl loss 214.149
#
#   EPOCH 89/100 	 train loss 1591.592 	 train nll loss 1568.226 	 train kl loss 233.667
#
#  val loss 3893.733 	 val nll loss 3873.202 	 val kl loss 205.306
#
#   EPOCH 90/100 	 train loss 1547.313 	 train nll loss 1524.661 	 train kl loss 226.523
#
#  val loss 3819.355 	 val nll loss 3799.399 	 val kl loss 199.562
#
#   EPOCH 91/100 	 train loss 1487.832 	 train nll loss 1465.978 	 train kl loss 218.545
#
#  val loss 3739.115 	 val nll loss 3718.993 	 val kl loss 201.219
#
#   EPOCH 92/100 	 train loss 1427.451 	 train nll loss 1406.049 	 train kl loss 214.025
#
#  val loss 3927.583 	 val nll loss 3906.752 	 val kl loss 208.312
#
#   EPOCH 93/100 	 train loss 1414.246 	 train nll loss 1392.909 	 train kl loss 213.366
#
#  val loss 3966.365 	 val nll loss 3945.254 	 val kl loss 211.107
#
#   EPOCH 94/100 	 train loss 1417.851 	 train nll loss 1396.658 	 train kl loss 211.927
#
#  val loss 3942.913 	 val nll loss 3922.779 	 val kl loss 201.347
#
#   EPOCH 95/100 	 train loss 1421.627 	 train nll loss 1400.703 	 train kl loss 209.236
#
#  val loss 3889.523 	 val nll loss 3868.905 	 val kl loss 206.181
#
#   EPOCH 96/100 	 train loss 1458.386 	 train nll loss 1437.427 	 train kl loss 209.589
#
#  val loss 3956.027 	 val nll loss 3935.771 	 val kl loss 202.559
#
#   EPOCH 97/100 	 train loss 1495.441 	 train nll loss 1474.344 	 train kl loss 210.971
#
#  val loss 3837.621 	 val nll loss 3817.414 	 val kl loss 202.064
#
#   EPOCH 98/100 	 train loss 1527.017 	 train nll loss 1505.932 	 train kl loss 210.843
#
#  val loss 3958.459 	 val nll loss 3939.437 	 val kl loss 190.217
#
#   EPOCH 99/100 	 train loss 1646.094 	 train nll loss 1625.280 	 train kl loss 208.140
#
#  val loss 4077.320 	 val nll loss 4058.024 	 val kl loss 192.969
#
#   EPOCH 100/100 	 train loss 1735.073 	 train nll loss 1713.999 	 train kl loss 210.744
#
#  val loss 3929.273 	 val nll loss 3907.809 	 val kl loss 214.642

# %%
plot_ae_outputs(vae.encoder,vae.decoder,n=10)

# %%
np.random.seed(random_seed)
random.seed(random_seed)
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)


batch_size = 50
epochs = 100
seqlen = 8

z_size = d
n_hidden = 256
n_gaussians = 20

# %%
def ToSeqData(dataset, seqlen):
    dataset_seq=[]

    for i in range(0,len(dataset)-(len(dataset)%seqlen),seqlen):
      
        dataset_seq.append(dataset[i:i+seqlen, :])
       
    dataset_seq=torch.stack(dataset_seq, dim=0)
    return dataset_seq

# %%
train_dataset = ToSeqData(train_data,seqlen)
val_dataset = ToSeqData(val_data,seqlen)
test_dataset =ToSeqData(test_data,seqlen)

# %%
batch_size=50

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
valid_loader = DataLoader(val_dataset, batch_size=batch_size, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, drop_last=True)


criterion = nn.BCELoss(reduction='sum')

# %%
class MDNRNN(nn.Module):
    def __init__(self, z_size, n_hidden=256, n_gaussians=10, n_layers=1,direction='forward'):
        super(MDNRNN, self).__init__()

        self.z_size = z_size
        self.n_hidden = n_hidden
        self.n_gaussians = n_gaussians
        self.n_layers = n_layers
        self.direction = direction
        
        self.lstm_cell = nn.LSTMCell(z_size,n_hidden)
        self.lstm = nn.LSTM(z_size, n_hidden, n_layers, batch_first=True)
        self.fc1 = nn.Linear(n_hidden, n_gaussians*z_size)
        self.fc2 = nn.Linear(n_hidden, n_gaussians*z_size)
        self.fc3 = nn.Linear(n_hidden, n_gaussians*z_size)
        
    def get_mixture_coef(self, y):
        pi, mu, sigma = self.fc1(y), self.fc2(y), self.fc3(y)
     
        pi = pi.view(-1, self.n_gaussians, self.z_size)
        mu = mu.view(-1, self.n_gaussians, self.z_size)
        sigma = sigma.view(-1, self.n_gaussians, self.z_size)
        
        pi = F.softmax(pi, 1)
        sigma = torch.exp(sigma)
        sigma = abs(sigma)
        return pi, mu, sigma
        
        
    def forward(self, data ,direct=None):

        if not direct:
            direct = self.direction
        
        if direct == "backward":
            data = data.flip(1)
       
        
        input_d = data[:,:,0,:,:] #size(10,6,64,64)
        input_m = data[:,:,1,:,:]

        output_pi = []
        output_mu = []
        output_sigma = []

        predict_result = []
        imputed_result = []
        latent_result = []
       
        h_c = (torch.zeros(data.size(0), self.n_hidden).to(device),
                torch.zeros(data.size(0), self.n_hidden).to(device))

        for t in range(input_d.size(1)):
            # get predict img by hidden
            h,_ = h_c
           
            pi, mu, sigma = self.get_mixture_coef(h)

            output_pi.append(pi)
            output_mu.append(mu)
            output_sigma.append(sigma)
          
            pi = pi.unsqueeze(1)
            mu = mu.unsqueeze(1)
            sigma = sigma.unsqueeze(1)
            
      
           
            # pi_t=pi.transpose(2, 3)
            # pi_t_r=pi_t.reshape(pi_t.size(0)*pi_t.size(1)*pi_t.size(2),pi_t.size(3))

            # rand_state = torch.random.get_rng_state()[0]
            

            # k = torch.multinomial(pi_t_r, 1).view(-1)
            
            # k_r = k.reshape(pi_t.size(0),pi_t.size(1),pi_t.size(2)).unsqueeze(2)

       
            # preds = torch.normal(mu, sigma).gather(2,k_r).squeeze(2).squeeze(1)

            preds = torch.sum((torch.normal(mu, sigma)*pi),dim=2).squeeze(1)
            preds_img = vae.decoder(preds).mean
                
            
            predict_result.append(preds_img)
            # combine input image and predict image
            input_t = input_d[:,t,:,:].unsqueeze(1)
            m = input_m[:,t,:,:].unsqueeze(1)
            input_c = input_t*m+preds_img*(1-m)
            imputed_result.append(input_c)
            # Get latent dimension by vae
           
            x = vae.encoder(input_c)

            latent_result.append(x)
            h_c = self.lstm_cell(x,h_c)
            
           

        # predict next image use for imputation next target

      
       
        pi_t = torch.stack(output_pi, dim=1)
        mu_t = torch.stack(output_mu, dim=1)
        sigma_t = torch.stack(output_sigma, dim=1)
        imputations = torch.stack(imputed_result, dim=1)
        predicts= torch.stack(predict_result, dim=1)
        latents = torch.stack(latent_result, dim=1).unsqueeze(2)
        if direct == "backward":
            pi_t=pi_t.flip(1)
            mu_t=mu_t.flip(1)
            sigma_t=sigma_t.flip(1)
            imputations=imputations.flip(1)
            predicts=predicts.flip(1)
            latents = latents.flip(1)
        return (pi_t,mu_t,sigma_t),predicts,imputations,latents

# %%
model = MDNRNN(z_size, n_hidden,n_gaussians).to(device)

# %%
def weighted_logsumexp(x,w, dim=None, keepdim=False):
    if dim is None:
        x, dim = x.view(-1), 0
    xm, _ = torch.max(x, dim, keepdim=True)
    x = torch.where(
        # to prevent nasty nan's
        (xm == float('inf')) | (xm == float('-inf')),
        xm,
        xm + torch.log(torch.sum(torch.exp(x - xm)*w, dim, keepdim=True)))
    return x if keepdim else x.squeeze(dim)

# %%
def mdn_loss_stable(y,pi,mu,sigma):
    m = torch.distributions.Normal(loc=mu, scale=sigma)
    m_lp_y = m.log_prob(y)
    loss = -weighted_logsumexp(m_lp_y,pi,dim=2)
    return loss.mean()

# %%
def mdn_loss_fn(y, pi, mu, sigma):
    m = torch.distributions.Normal(loc=mu, scale=sigma)
    loss = torch.exp(m.log_prob(y))
    loss = torch.sum(loss * pi, dim=2)
    loss = -torch.log(loss)
    return loss.mean()

# %%
optimizer = torch.optim.Adam(model.parameters())

# %%
for epoch in range(100):
    # Set initial hidden and cell states
    train_loss = 0
    prediction_loss = 0
    imputation_loss = 0
    
    for x in train_loader:
        x = x.to(device)
    
        optimizer.zero_grad()
        # Get mini-batch inputs and targets
        masks = torch.ones(x.shape).to(device)

        inputs = torch.cat((x,masks),dim=2).to(device)
       
        # Forward pass
        (pi, mu, sigma),predict, imputation,latents = model(inputs)

        # latent = latents[:,-1:,:,:]
        # pi = pi[:,-1:,:,:]
        # mu = mu[:,-1:,:,:]
        # sigma = sigma[:,-1:,:,:]
        loss = mdn_loss_stable(latents, pi, mu, sigma)
        
        # Backward and optimize
        
        loss.backward()
        # clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
        train_loss += loss.item()
    
    for x in valid_loader:
        
        model.eval()
        with torch.no_grad():
            x = x.to(device)
            
            x_target = x[:,-1:,:,:,:]
            masks = torch.ones(x.shape).to(device)
            inputs = torch.cat((x,masks),dim=2)
         
            (pi, mu, sigma),predicts, imputation,latents = model(inputs)
            predict = predicts[:,-1:,:,:,:]
            predict_loss = criterion(x_target.flatten(), predict.flatten())  
            # predict_loss = ((x_target-predict)**2).sum()
            
          
            prediction_loss += predict_loss.item()
            

    print ('Epoch [{}/{}], Loss: {:.4f}, Prediction_Loss:{:.4f},  '
               .format(epoch+1, num_epochs, train_loss, prediction_loss/len(valid_loader)))
# Out:
# Epoch [1/100], Loss: 29.1753, Prediction_Loss:1016727.1250,
# Epoch [2/100], Loss: 22.1916, Prediction_Loss:710549.3750,
# Epoch [3/100], Loss: 19.4898, Prediction_Loss:593646.1562,
# Epoch [4/100], Loss: 18.4906, Prediction_Loss:588842.4062,
# Epoch [5/100], Loss: 17.9483, Prediction_Loss:570653.7500,
# Epoch [6/100], Loss: 16.9657, Prediction_Loss:558893.1875,
# Epoch [7/100], Loss: 16.5340, Prediction_Loss:512866.0938,
# Epoch [8/100], Loss: 16.0907, Prediction_Loss:511940.4219,
# Epoch [9/100], Loss: 15.4960, Prediction_Loss:512176.8750,
# Epoch [10/100], Loss: 14.8867, Prediction_Loss:496265.3281,
# Epoch [11/100], Loss: 14.2363, Prediction_Loss:498163.2031,
# Epoch [12/100], Loss: 13.8667, Prediction_Loss:496487.5625,
# Epoch [13/100], Loss: 13.2791, Prediction_Loss:491837.4688,
# Epoch [14/100], Loss: 13.0224, Prediction_Loss:486332.7031,
# Epoch [15/100], Loss: 12.6454, Prediction_Loss:492844.2188,
# Epoch [16/100], Loss: 12.1822, Prediction_Loss:484720.2344,
# Epoch [17/100], Loss: 12.4741, Prediction_Loss:485513.8750,
# Epoch [18/100], Loss: 11.9292, Prediction_Loss:482850.8125,
# Epoch [19/100], Loss: 11.4395, Prediction_Loss:486568.2656,
# Epoch [20/100], Loss: 11.1544, Prediction_Loss:479965.8438,
# Epoch [21/100], Loss: 11.2106, Prediction_Loss:486262.8594,
# Epoch [22/100], Loss: 10.7412, Prediction_Loss:491486.7812,
# Epoch [23/100], Loss: 10.7780, Prediction_Loss:486400.9219,
# Epoch [24/100], Loss: 10.7561, Prediction_Loss:488274.6406,
# Epoch [25/100], Loss: 10.5484, Prediction_Loss:488324.2969,
# Epoch [26/100], Loss: 10.4672, Prediction_Loss:485090.0625,
# Epoch [27/100], Loss: 10.1684, Prediction_Loss:486841.6719,
# Epoch [28/100], Loss: 10.1281, Prediction_Loss:487576.2031,
# Epoch [29/100], Loss: 9.8955, Prediction_Loss:486007.5156,
# Epoch [30/100], Loss: 9.9149, Prediction_Loss:488636.5156,
# Epoch [31/100], Loss: 9.7299, Prediction_Loss:491497.2344,
# Epoch [32/100], Loss: 9.5299, Prediction_Loss:487910.4062,
# Epoch [33/100], Loss: 9.8468, Prediction_Loss:490804.3125,
# Epoch [34/100], Loss: 9.4958, Prediction_Loss:484103.5625,
# Epoch [35/100], Loss: 9.1320, Prediction_Loss:492803.0625,
# Epoch [36/100], Loss: 8.9681, Prediction_Loss:484212.4844,
# Epoch [37/100], Loss: 9.0810, Prediction_Loss:485741.6250,
# Epoch [38/100], Loss: 8.7519, Prediction_Loss:489955.6875,
# Epoch [39/100], Loss: 8.8369, Prediction_Loss:483163.2344,
# Epoch [40/100], Loss: 8.8442, Prediction_Loss:490663.1562,
# Epoch [41/100], Loss: 8.6854, Prediction_Loss:488622.6250,
# Epoch [42/100], Loss: 8.6877, Prediction_Loss:482358.3906,
# Epoch [43/100], Loss: 8.4299, Prediction_Loss:487445.3906,
# Epoch [44/100], Loss: 8.4367, Prediction_Loss:486484.3750,
# Epoch [45/100], Loss: 8.2632, Prediction_Loss:486666.9688,
# Epoch [46/100], Loss: 8.3261, Prediction_Loss:491440.3750,
# Epoch [47/100], Loss: 8.1772, Prediction_Loss:494486.9375,
# Epoch [48/100], Loss: 8.0418, Prediction_Loss:488823.7344,
# Epoch [49/100], Loss: 8.3145, Prediction_Loss:489563.6562,
# Epoch [50/100], Loss: 8.0361, Prediction_Loss:486774.0625,
# Epoch [51/100], Loss: 7.7610, Prediction_Loss:496186.7812,
# Epoch [52/100], Loss: 7.6080, Prediction_Loss:486246.7812,
# Epoch [53/100], Loss: 7.6936, Prediction_Loss:487612.3906,
# Epoch [54/100], Loss: 7.3892, Prediction_Loss:492969.4531,
# Epoch [55/100], Loss: 7.5104, Prediction_Loss:487259.9062,
# Epoch [56/100], Loss: 7.5267, Prediction_Loss:493229.8438,
# Epoch [57/100], Loss: 7.4137, Prediction_Loss:488522.1719,
# Epoch [58/100], Loss: 7.4117, Prediction_Loss:485432.7656,
# Epoch [59/100], Loss: 7.2319, Prediction_Loss:488670.6562,
# Epoch [60/100], Loss: 7.2164, Prediction_Loss:485829.9219,
# Epoch [61/100], Loss: 7.0684, Prediction_Loss:492197.2344,
# Epoch [62/100], Loss: 7.1664, Prediction_Loss:493911.6250,
# Epoch [63/100], Loss: 7.0476, Prediction_Loss:493437.5938,
# Epoch [64/100], Loss: 6.9661, Prediction_Loss:486995.3750,
# Epoch [65/100], Loss: 7.1607, Prediction_Loss:488329.4219,
# Epoch [66/100], Loss: 6.9261, Prediction_Loss:488500.5625,
# Epoch [67/100], Loss: 6.6505, Prediction_Loss:494978.9531,
# Epoch [68/100], Loss: 6.5531, Prediction_Loss:487802.3125,
# Epoch [69/100], Loss: 6.6911, Prediction_Loss:489365.4844,
# Epoch [70/100], Loss: 6.4800, Prediction_Loss:492300.7656,
# Epoch [71/100], Loss: 6.5380, Prediction_Loss:489493.8906,
# Epoch [72/100], Loss: 6.5555, Prediction_Loss:489141.5938,
# Epoch [73/100], Loss: 6.4162, Prediction_Loss:487568.0781,
# Epoch [74/100], Loss: 6.3946, Prediction_Loss:487234.7344,
# Epoch [75/100], Loss: 6.2268, Prediction_Loss:490802.9531,
# Epoch [76/100], Loss: 6.2403, Prediction_Loss:488332.0625,
# Epoch [77/100], Loss: 6.1253, Prediction_Loss:494326.8750,
# Epoch [78/100], Loss: 6.2496, Prediction_Loss:492903.1719,
# Epoch [79/100], Loss: 6.1975, Prediction_Loss:492353.5938,
# Epoch [80/100], Loss: 6.1056, Prediction_Loss:486675.6562,
# Epoch [81/100], Loss: 6.3172, Prediction_Loss:490043.5312,
# Epoch [82/100], Loss: 6.1028, Prediction_Loss:490312.4062,
# Epoch [83/100], Loss: 5.8805, Prediction_Loss:494035.6562,
# Epoch [84/100], Loss: 5.7303, Prediction_Loss:486236.9531,
# Epoch [85/100], Loss: 5.8429, Prediction_Loss:492966.1719,
# Epoch [86/100], Loss: 5.5890, Prediction_Loss:493632.6094,
# Epoch [87/100], Loss: 5.6578, Prediction_Loss:487689.7969,
# Epoch [88/100], Loss: 5.6899, Prediction_Loss:490442.0938,
# Epoch [89/100], Loss: 5.6056, Prediction_Loss:489334.9375,
# Epoch [90/100], Loss: 5.6291, Prediction_Loss:486118.8750,
# Epoch [91/100], Loss: 5.4924, Prediction_Loss:491823.4531,
# Epoch [92/100], Loss: 5.4901, Prediction_Loss:489755.9219,
# Epoch [93/100], Loss: 5.4043, Prediction_Loss:493672.7656,
# Epoch [94/100], Loss: 5.5025, Prediction_Loss:491136.7188,
# Epoch [95/100], Loss: 5.4401, Prediction_Loss:493453.2656,
# Epoch [96/100], Loss: 5.3631, Prediction_Loss:485232.8750,
# Epoch [97/100], Loss: 5.5493, Prediction_Loss:489730.5938,
# Epoch [98/100], Loss: 5.3633, Prediction_Loss:488738.5781,
# Epoch [99/100], Loss: 5.1686, Prediction_Loss:492965.9688,
# Epoch [100/100], Loss: 5.0552, Prediction_Loss:486800.1406,

# %%
one = np.random.randint(len(test_dataset))
one = 88
x = test_dataset[one].to(device)
mask = torch.ones(x.shape).to(device)

input = torch.cat((x,mask),dim=1).unsqueeze(0)

y_origin = x
print(input.shape)
(pi, mu, sigma),predicts, imputation,latents = model(input)
predict = predicts[:,-1:,:,:]

# y_preds = [torch.normal(mu, sigma)[:, :, i, :] for i in range(n_gaussians)]

# y_preds=torch.sum((torch.normal(mu, sigma)*pi),dim=2)

# y_preds  = torch.normal(mu, sigma).gather(2,pi.max(2)[1].unsqueeze(2)).squeeze(2)

# pi_t=pi.transpose(2, 3)
# pi_t_r=pi_t.reshape(pi_t.size(0)*pi_t.size(1)*pi_t.size(2),pi_t.size(3))
# k = torch.multinomial(pi_t_r, 1).view(-1)
# k_r = k.reshape(pi_t.size(0),pi_t.size(1),pi_t.size(2)).unsqueeze(2)
# y_preds = torch.normal(mu, sigma).gather(2,k_r).squeeze(2)

# compare_result=torch.cat([x,y]+y_preds)
fig, axs = plt.subplots(1, 9,figsize=(40,90))


print(predict.sum())
axs[0].imshow(y_origin[0][0].detach().cpu().numpy(),cmap='jet')
axs[1].imshow(y_origin[1][0].detach().cpu().numpy(),cmap='jet')
axs[2].imshow(y_origin[2][0].detach().cpu().numpy(),cmap='jet')
axs[3].imshow(y_origin[3][0].detach().cpu().numpy(),cmap='jet')
axs[4].imshow(y_origin[4][0].detach().cpu().numpy(),cmap='jet')
axs[5].imshow(y_origin[5][0].detach().cpu().numpy(),cmap='jet')
axs[6].imshow(y_origin[6][0].detach().cpu().numpy(),cmap='jet')
axs[7].imshow(y_origin[7][0].detach().cpu().numpy(),cmap='jet')

axs[8].imshow(predict[0][0][0].detach().cpu().numpy(),cmap='jet')
print(((predict[0][0][0]-y_origin[2][0])**2).sum())

# for z_result in compare_result:
#     vae.decoder.eval()
#     with torch.no_grad():
#         d_image=vae.decoder(z_result)
#         plt.imshow(d_image.cpu().squeeze().numpy(), cmap='gray')
#         plt.show()
# Out:
# torch.Size([1, 8, 2, 96, 135])
# tensor(1561.6935, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(41.4117, device='cuda:0', grad_fn=<SumBackward0>)

# %%
one = np.random.randint(len(test_dataset))
one =88
x = test_dataset[one].to(device)
mask = torch.ones(x.shape).to(device)
predict_length = 7
predict_result = []
origin_input = x
for i in range(predict_length):
    input = torch.cat((x,mask),dim=1).unsqueeze(0)
   
    (pi, mu, sigma),predicts, imputation,latents = model(input)
    predict = predicts[:,-1:,:,:].squeeze(0)
    predict_result.append(predict)
    x = torch.cat([x[1:],predict])

fig, axs = plt.subplots(3, 7,figsize=(40,10))
for i in range(x.size(0)-1):
    axs[0,i].imshow(origin_input[i][0].detach().cpu().numpy(),cmap='jet')

for j in range(len(predict_result)):
    
    axs[1,j].imshow(predict_result[j][0][0].detach().cpu().numpy(),cmap='jet')

truth =torch.cat([origin_input[-1:], test_dataset[one+1][:predict_length].to(device)])

for k in range(x.size(0)-1):
    axs[2,k].imshow(truth[k][0].detach().cpu().numpy(),cmap='jet')

# %%
def ssim(img1, img2):
    C1 = (0.01 * 1)**2
    C2 = (0.03 * 1)**2

    kernel = cv2.getGaussianKernel(11, 1.5)
    window = np.outer(kernel, kernel.transpose())

    mu1 = cv2.filter2D(img1, -1, window)[5:-5, 5:-5]  # valid
    mu2 = cv2.filter2D(img2, -1, window)[5:-5, 5:-5]
    mu1_sq = mu1**2
    mu2_sq = mu2**2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = cv2.filter2D(img1**2, -1, window)[5:-5, 5:-5] - mu1_sq
    sigma2_sq = cv2.filter2D(img2**2, -1, window)[5:-5, 5:-5] - mu2_sq
    sigma12 = cv2.filter2D(img1 * img2, -1, window)[5:-5, 5:-5] - mu1_mu2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) *
                                                            (sigma1_sq + sigma2_sq + C2))
    return ssim_map.mean()


def calculate_ssim(img1, img2):
    '''calculate SSIM
    the same outputs as MATLAB's
    img1, img2: [0, 255]
    '''
    if not img1.shape == img2.shape:
        raise ValueError('Input images must have the same dimensions.')
    if img1.ndim == 2:
        return ssim(img1, img2)
    elif img1.ndim == 3:
        if img1.shape[2] == 3:
            ssims = []
            for i in range(3):
                ssims.append(ssim(img1, img2))
            return np.array(ssims).mean()
        elif img1.shape[2] == 1:
            return ssim(np.squeeze(img1), np.squeeze(img2))
    else:
        raise ValueError('Wrong input image dimensions.')

# %%
test_predict_loss = 0.0
test_mse_loss = 0.0

with torch.no_grad():
    for i in range(len(test_dataset)):

        x = test_dataset[i].to(device)
        mask = torch.ones(x.shape).to(device)
        input = torch.cat((x,mask),dim=1).unsqueeze(0)
     
       

        (pi, mu, sigma),predicts, imputation,latents = model(input)
       
        # predicts = vae.decoder(vae.encoder(imputation[0])).mean
        predict = predicts[:,-1:,:,:]
        y_img = x[-1:,:,:,:]
        loss_p = (abs(predict - y_img)/(predicts.size(-1)*predicts.size(-2))).sum()
      
        mse = (((predicts- y_img)**2)/(predicts.size(-1)*predicts.size(-2))).sum()
        test_predict_loss += loss_p
        test_mse_loss += mse
       


print(test_predict_loss / len(test_dataset))
print(test_mse_loss / len(test_dataset))
# Out:
# tensor(0.0385, device='cuda:0')
# tensor(0.0716, device='cuda:0')

# %% [markdown]
# 0.030602442547678948
# 0.04794726518177093
# 18.373459759169872
# 0.8157171804308895
#
# 0.0316610941849649
# 0.0505340079886593
# 18.09755197754493
# 0.8067896990180017

# %%
one = np.random.randint(len(test_dataset))
x = test_dataset[one].to(device)
mask = torch.ones(x.shape).to(device)

input = torch.cat((x,mask),dim=1).unsqueeze(0)

y_origin = x[-3:,:,:,:]
print(input.shape)
(pi, mu, sigma),predicts, imputation,latents = model(input)
predict = predicts[:,-1:,:,:]

# y_preds = [torch.normal(mu, sigma)[:, :, i, :] for i in range(n_gaussians)]

# y_preds=torch.sum((torch.normal(mu, sigma)*pi),dim=2)

# y_preds  = torch.normal(mu, sigma).gather(2,pi.max(2)[1].unsqueeze(2)).squeeze(2)

# pi_t=pi.transpose(2, 3)
# pi_t_r=pi_t.reshape(pi_t.size(0)*pi_t.size(1)*pi_t.size(2),pi_t.size(3))
# k = torch.multinomial(pi_t_r, 1).view(-1)
# k_r = k.reshape(pi_t.size(0),pi_t.size(1),pi_t.size(2)).unsqueeze(2)
# y_preds = torch.normal(mu, sigma).gather(2,k_r).squeeze(2)

# compare_result=torch.cat([x,y]+y_preds)
fig, axs = plt.subplots(1, 4,figsize=(40,90))

axs[0].imshow(predict[0][0][0].detach().cpu().numpy(),cmap='gray', vmin=0, vmax=1)
print(predict.sum())
axs[1].imshow(y_origin[0][0].detach().cpu().numpy(),cmap='gray',vmin=0, vmax=1)

axs[2].imshow(y_origin[1][0].detach().cpu().numpy(),cmap='gray',vmin=0, vmax=1)
axs[3].imshow(y_origin[2][0].detach().cpu().numpy(),cmap='gray',vmin=0, vmax=1)
print(((predict[0][0][0]-y_origin[2][0])**2).sum())

# for z_result in compare_result:
#     vae.decoder.eval()
#     with torch.no_grad():
#         d_image=vae.decoder(z_result)
#         plt.imshow(d_image.cpu().squeeze().numpy(), cmap='gray')
#         plt.show()
# Out:
# torch.Size([1, 8, 2, 96, 135])
# tensor(1472.6431, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(25.5955, device='cuda:0', grad_fn=<SumBackward0>)

# %%
x = [0,1,2,3,4]

# %%
x[-3:]
# Out:
# [2, 3, 4]
